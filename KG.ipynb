# %% [markdown]
# # IMPORTS

# %%
import pandas as pd 
import os
import json
import numpy as np

# from spacy.matcher import Matcher 
# from spacy.tokens import Span 

import networkx as nx

import matplotlib.pyplot as plt
from tqdm import tqdm
import re
from nltk.tokenize import sent_tokenize

from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, AutoModelForCausalLM
import math
import torch
import IPython
from pyvis.network import Network
import wikipedia

import pickle
import textwrap

from joblib import Parallel, delayed
import multiprocessing
from collections import Counter, defaultdict

from functools import partial
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from fuzzywuzzy import fuzz
# Out:
# e:\Downloads\WeLearn\9th Sem\nineSemEnv\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# # OFFLINE WIKI CLASS

# %%
from WikiDump_Search.wikiDumpSearch import offline_Wiki

# %% [markdown]
# # KB CLASS

# %%
class KB():
    def __init__(self):
        self.entities = {} # { entity_title: {...} }
        self.relations = [] # [ head: entity_title, type: ..., tail: entity_title,
          # meta: { article_url: { spans: [...] } } ]
        self.sources = {} # { article_url: {...} }

    def merge_with_kb(self, kb2):
        for r in kb2.relations:
            article_url = list(r["meta"].keys())[0]
            source_data = kb2.sources[article_url]
            self.add_relation(r, source_data["article_title"],
                              source_data["article_publish_date"])

    def are_relations_equal(self, r1, r2):
        return all(r1[attr] == r2[attr] for attr in ["head", "type", "tail"])

    def exists_relation(self, r1):
        return any(self.are_relations_equal(r1, r2) for r2 in self.relations)

    def merge_relations(self, r2):
        r1 = [r for r in self.relations
              if self.are_relations_equal(r2, r)][0]

        # if different article
        article_url = list(r2["meta"].keys())[0]
        if article_url not in r1["meta"]:
            r1["meta"][article_url] = r2["meta"][article_url]

        # if existing article
        
        else:
            spans_to_add = [span for span in r2["meta"][article_url]["spans"]
                            if span not in r1["meta"][article_url]["spans"]]
            r1["meta"][article_url]["spans"] += spans_to_add
            

    def get_wikipedia_data(self, candidate_entity, useWiki = True, offline_wiki = None, verbose = False):
        # print("\n\n--- offline", offline_Wiki)
        entity_data = None
        stop_words = set(stopwords.words('english'))
        if len(candidate_entity.split()) > 4:
            word_tokens = word_tokenize(candidate_entity)
            candidate_entity = " ".join([w for w in word_tokens if not w.lower() in stop_words])

        try:
            if offline_wiki:
                if verbose:
                    print(f"Finding {candidate_entity} in offline Wiki")
                _entity_data = offline_wiki.word_match(candidate_entity, verbose = verbose)
                
                if verbose:
                    print(f"Got {_entity_data} after word_match from offline Wiki")

                if "REDIRECT" in _entity_data["summary"][:10]:
                    entity_data = _entity_data
                else:                    
                    ratioo = fuzz.ratio(candidate_entity, _entity_data['title'])
                    if verbose:
                        print(f"Fuzz ration : {ratioo}")
                    if ratioo > 50 :
                        entity_data = _entity_data
                        if verbose:
                            print(f"Got {entity_data} from offline wiki with similarity ration = {ratioo}.")
            
            if useWiki and not entity_data:
                if verbose:
                    print(f"Finding {candidate_entity} in online Wiki")
                page = wikipedia.page(candidate_entity, auto_suggest=False)
                entity_data = {
                    "title": page.title,
                    "url": page.url,
                    "summary": page.summary
                }
            
            return entity_data
        except:
            return None

    def add_entity(self, e):
        self.entities[e["title"]] = {k:v for k,v in e.items() if k != "title"}

    def add_relation(self, r, article_title, article_publish_date, 
                     useWiki = True, offlineWiki = None, verbose = False):
        # check on wikipedia
        candidate_entities = [r["head"], r["tail"]]
        if verbose:
            print(f"Candidate entities : {candidate_entities}")
            
        # entities = [self.get_wikipedia_data(ent) for ent in candidate_entities]
        
        # TRY 2
        entities = []
        if useWiki:
            entities = Parallel(n_jobs=N_JOB_COUNT)(delayed(self.get_wikipedia_data)(ent, useWiki, offlineWiki, verbose=verbose) for ent in candidate_entities)
            # entities = [self.get_wikipedia_data(ent, useWiki, offlineWiki) for ent in candidate_entities]

        else:
            entities = [{"title": ent,
                         "url": "",
                         "summary": ""
                        } for ent in candidate_entities]

        # if one entity does not exist, stop
        if any(ent is None for ent in entities):
            return

        # manage new entities
        for e in entities:
            self.add_entity(e)

        # rename relation entities with their wikipedia titles
        r["head"] = entities[0]["title"]
        r["tail"] = entities[1]["title"]

        # add source if not in kb
        article_url = list(r["meta"].keys())[0]
        if article_url not in self.sources:
            self.sources[article_url] = {
                "article_title": article_title,
                "article_publish_date": article_publish_date
            }

        # manage new relation
        if not self.exists_relation(r):
            self.relations.append(r)
        else:
            self.merge_relations(r)

    def print(self):
        print("Entities:")
        for e in self.entities.items():
            print(f"  {e}")
        print("Relations:")
        for r in self.relations:
            print(f"  {r}")
        print("Sources:")
        for s in self.sources.items():
            print(f"  {s}")

# %% [markdown]
# # FOR GPU

# %%
def get_cpu_count():
    c = multiprocessing.cpu_count()
    return c 

def check_gpu():
    for i in range(torch.cuda.device_count()):
        device_name = f'cuda:{i}'
        print(f'{i} device name:{torch.cuda.get_device_name(torch.device(device_name))}')

def get_gpu():
    return [f'cuda:{i}' for i in range(torch.cuda.device_count())]

print(check_gpu())

print(get_gpu())

print(get_cpu_count())

N_JOB_COUNT = get_cpu_count()//2
N_JOB_COUNT = -1 # PARALLEL CAUSES ERROR, SO KEEPING IT 1
N_JOB_COUNT = 4
# Out:
# 0 device name:NVIDIA GeForce RTX 3060 Laptop GPU
# None
# ['cuda:0']
# 16

# %% [markdown]
# # HELPER FUNCTION

# %%
def loadJSON(filepathh):
    _dataa = {} 
    if os.path.exists(filepathh):
        with open(filepathh, "r", encoding="utf-8") as _f:
            _dataa = json.load(_f)
    else:
        print(f"{filepathh} does not exists...\n") 
    return _dataa 

def loadTXT(filepathh):
    _dataa = ""
    if os.path.exists(filepathh):
        with open(filepathh, "r", encoding="utf-8") as _f:
            _dataa = _f.read()
    else:
        print(f"{filepathh} does not exists...\n") 
    return _dataa 

def loadFILE(filepathh = ""):
    if os.path.exists(filepathh):
        if filepathh.endswith(".txt"):
            return loadTXT(filepathh)
        elif filepathh.endswith(".json"):
            return loadJSON(filepathh)
        else:
            print("\n- Invalid File format 😐 !!!\n")
            return None
    else:
        print(f"{filepathh} does not exists...\n") 

def remove_garbage(text):
    # Remove garbage Unicode characters
    cleaned_text = text.encode().decode('unicode-escape')
    # Remove any remaining non-printable characters
    cleaned_text = re.sub(r'[^\x20-\x7E]', '', cleaned_text)
    return cleaned_text

def clean_sentence(sentence):
    # Remove extra white spaces
    cleaned_sentence = re.sub(r'\s+', ' ', sentence)
    # Remove unwanted characters except alphabets, numbers, punctuation marks, '@', '-', and '_'
    cleaned_sentence = re.sub(r'[^a-zA-Z0-9@#\-_.,?!\'" ]', '', cleaned_sentence)
    # Remove words containing '#' and 'pic.twitter.com'
    cleaned_sentence = ' '.join(word if '#' not in word and 'pic.twitter.com' not in word else ' ' for word in cleaned_sentence.split() )
    return cleaned_sentence.strip()

def clean_document(document):
    document = remove_garbage(document)
    # Tokenize the document into sentences
    sentences = sent_tokenize(document)
    # Clean each sentence
    cleaned_sentences = [clean_sentence(sentence) for sentence in sentences]
    return cleaned_sentences

# %%
def save_network_html(kb, filename="network.html", 
                      verbose = False, 
                      physics = False,
                      show = False):

    if not os.path.exists(filename):
        with open(filename, 'w') as _file:
            _file.write("")

    # create network
    G = nx.Graph()
    net = Network(directed=True, 
                  notebook=True,
                  width="1000px", 
                  height="1000px",
                #   bgcolor="#eeeeee"
                )
    if verbose:
        print("Network initialized")

    # nodes
    color_entity = "#00FF00"
    if verbose:
        print(f"there are {len(kb.entities)} entities in KB")
    for e in kb.entities:
        G.add_node(e)
        net.add_node(e, label=e, shape="dot", color=color_entity)
        # net.add_node(e, label=e, physics = physics, shape="dot", color=color_entity)
    
    # edges
    if verbose:
        print(f"there are {len(kb.relations)} relations in KB")
    
    # for r in kb.relations:
    #     G.add_edge(r['head'], r["tail"], )
    #     # net.add_edge(r["head"], r["tail"], title=r["type"], label=r["type"])
    labels = {}
    for r in kb.relations:
        G.add_edge(r['head'], r["tail"])
        labels[(r["head"], r["tail"])] = r["type"]
        net.add_edge(r["head"], r["tail"], title=r["type"], label=r["type"])

    scale=10 # Scaling the size of the nodes by 10*degree
    d = dict(G.degree)

    pos = nx.spring_layout(G)
    #Updating dict
    d.update((x, scale*y) for x, y in d.items())

    #Setting up size attribute
    nx.set_node_attributes(G,d,'size')
    nx.set_edge_attributes(G,labels, 'labels')
    # nx.draw_networkx_edge_labels(
    #                             G, pos,
    #                             edge_labels=labels,
    #                             # font_color='red'
    #                             )
    if verbose:
        print(f"Trying to make graph")

    # net.from_nx(G)   
    
    # save network
    if physics:
        net.repulsion(
            node_distance=200,
            central_gravity=0.3,
            spring_length=200,
            spring_strength=0.05,
            damping=0.09
        )

    net.set_edge_smooth('dynamic')

    if verbose:
        print(f"Trying to show graph")

    net.show(filename)

def save_kb(kb, filename, verbose = False):
    if verbose:
        print(f"there are {len(kb.entities)} entities in KB")
        print(f"there are {len(kb.relations)} relations in KB")

    with open(filename, "wb") as f:
        pickle.dump(kb, f)

def load_kb(filename):
    res = None
    with open(filename, "rb") as f:
        res = pickle.load(f)
    return res

# %% [markdown]
# # DOING NER

# %%
def extract_relations_from_model_output(text):
    relations = []
    relation, subject, relation, object_ = '', '', '', ''
    text = text.strip()
    current = 'x'
    text_replaced = text.replace("<s>", "").replace("<pad>", "").replace("</s>", "")
    for token in text_replaced.split():
        if token == "<triplet>":
            current = 't'
            if relation != '':
                relations.append({
                    'head': subject.strip(),
                    'type': relation.strip(),
                    'tail': object_.strip()
                })
                relation = ''
            subject = ''
        elif token == "<subj>":
            current = 's'
            if relation != '':
                relations.append({
                    'head': subject.strip(),
                    'type': relation.strip(),
                    'tail': object_.strip()
                })
            object_ = ''
        elif token == "<obj>":
            current = 'o'
            relation = ''
        else:
            if current == 't':
                subject += ' ' + token
            elif current == 's':
                object_ += ' ' + token
            elif current == 'o':
                relation += ' ' + token
    if subject != '' and relation != '' and object_ != '':
        relations.append({
            'head': subject.strip(),
            'type': relation.strip(),
            'tail': object_.strip()
        })
    return relations

# %%
def split_docs(text, 
               max_text_count = 1000,
               verbose = False):
    
    sentences = sent_tokenize(text)
    chunks = []
    chunk = ""
    len_sentence = 0
    chunk_len = 0
    for sentence in sentences:
      len_sentence = len(sentence.strip().split())
      if chunk_len+len_sentence < max_text_count:
         chunk += sentence+" "
         chunk_len += len_sentence
         continue
      chunk_len = len_sentence
      chunks.append(chunk)
      chunk = sentence
      
      # chunk = textwrap.wrap(sentence, max_text_count)
    if verbose:
      print(len(chunks))
    return chunks

def _from_text_to_kb(text, article_url, kb = None,
                    useGPU=0, 
                    span_length=128, 
                    article_title=None,
                    article_publish_date=None, 
                    verbose=False,
                    useWiki=True,
                    offline_Wiki = None):
    
    # tokenize whole text
    # print(text)
    # input()
    with torch.no_grad():
        inputs = tokenizer([text], 
                        max_length = 1000,
                        #    max_length=512,
                        padding=True,  
                        truncation=True, 
                        return_tensors="pt")

        # compute span boundaries
        # print(inputs.values())
        num_tokens = len(inputs["input_ids"][0])
        if verbose:
            print(f"Input has {num_tokens} tokens")
        num_spans = math.ceil(num_tokens / span_length)
        
        if verbose:
            print(f"Input has {num_spans} spans")
        overlap = math.ceil((num_spans * span_length - num_tokens) / 
                            max(num_spans - 1, 1))
        
        # input()
        spans_boundaries = []
        start = 0
        for i in range(num_spans):
            spans_boundaries.append([start + span_length * i,
                                    start + span_length * (i + 1)])
            start -= overlap
        if verbose:
            print(f"Span boundaries are {spans_boundaries}")

        # transform input with spans
        tensor_ids = [inputs["input_ids"][0][boundary[0]:boundary[1]]
                    for boundary in spans_boundaries]
        tensor_masks = [inputs["attention_mask"][0][boundary[0]:boundary[1]]
                        for boundary in spans_boundaries]
        inputs = {
            "input_ids": torch.stack(tensor_ids),
            "attention_mask": torch.stack(tensor_masks)
        }
        
        # generate relations
        num_return_sequences = 3
        gen_kwargs = {
            "max_length": 256,
            "length_penalty": 0,
            "num_beams": 3,
            "num_return_sequences": num_return_sequences
        }

        generated_tokens = model.generate(
                                            inputs["input_ids"].to(model.device),
                                            attention_mask=inputs["attention_mask"].to(model.device),
                                            **gen_kwargs,
                                            )

        # decode relations
        decoded_preds = tokenizer.batch_decode(generated_tokens,
                                            skip_special_tokens=False)

        # create kb
        if not kb:
            kb = KB()

        i = 0
        # for sentence_pred in tqdm(decoded_preds, leave=False):
        _relations = Parallel(n_jobs=N_JOB_COUNT)(delayed(extract_relations_from_model_output)(sentence_pred) for sentence_pred in decoded_preds)

        for sentence_pred in decoded_preds:
            current_span_index = i // num_return_sequences
            # relations = extract_relations_from_model_output(sentence_pred)
            relations = _relations[i]

            if verbose:
                print(f"{i}. extraction of relations done, it has {len(relations)} relations", end="\r")
                
            for relation in relations:
                relation["meta"] = {
                    article_url: {
                        "spans": [spans_boundaries[current_span_index]]
                    }
                }
                kb.add_relation(relation, 
                                article_title,
                                article_publish_date, 
                                useWiki=useWiki,
                                offlineWiki=offline_Wiki,
                                verbose=verbose)
            i += 1

    return kb

def from_text_to_kb(text, article_url, kb = None,
                    useGPU=0, 
                    span_length=128, 
                    article_title=None,
                    article_publish_date=None, 
                    verbose=False,
                    max_token = 1000,
                    max_doc_text = 1000,
                    useWiki = True,
                    offlineWiki = None):
    # with torch.no_grad():
    #     # tokenize whole text
    #     # inputs = tokenizer([text], return_tensors="pt")
    #     # num_tokens = len(inputs["input_ids"][0])

    input_words = text.split()
    num_tokens = len(input_words)

    if verbose:
        # print(f"Input has {num_tokens} tokens")
        print(f"Input has {num_tokens} words")

    if not kb:
        kb = KB()
    
    _kb = kb 

    _offlineWiki = offlineWiki

    # compute span boundaries
    # num_tokens = len(inputs["input_ids"][0])
    if num_tokens > max_token:
        if verbose:
            print("input len > token size, splitting doc in smaller chunks")
        text = split_docs(text, max_text_count=max_doc_text)
    
    if type(text) == str:
        text = [text]
    
    # for _text in tqdm(text, leave=False):
    for _text in text: 
        # print(_text)
        # print(_text[0])
        # input()
        _kb = _from_text_to_kb(_text, article_url, 
                            useGPU=useGPU, 
                            span_length=span_length, 
                            article_title=article_title,
                            article_publish_date=article_publish_date, 
                            verbose=verbose,
                            kb=_kb,
                            useWiki=useWiki,
                            offline_Wiki=_offlineWiki)
    return _kb

# %%
def save_network_html(kb, filename="network.html", 
                      verbose = False, 
                      physics = False,
                      show = False):

    if not os.path.exists(filename):
        with open(filename, 'w') as _file:
            _file.write("")

    # create network
    G = nx.Graph()
    net = Network(directed=True, 
                  notebook=True,
                  width="1000px", 
                  height="1000px",
                #   bgcolor="#eeeeee"
                )
    if verbose:
        print("Network initialized")

    # nodes
    color_entity = "#00FF00"
    if verbose:
        print(f"there are {len(kb.entities)} entities in KB")
    for e in kb.entities:
        G.add_node(e)
        net.add_node(e, label=e, shape="dot", color=color_entity)
        # net.add_node(e, label=e, physics = physics, shape="dot", color=color_entity)
    
    # edges
    if verbose:
        print(f"there are {len(kb.relations)} relations in KB")
    
    # for r in kb.relations:
    #     G.add_edge(r['head'], r["tail"], )
    #     # net.add_edge(r["head"], r["tail"], title=r["type"], label=r["type"])
    labels = {}
    for r in kb.relations:
        G.add_edge(r['head'], r["tail"])
        labels[(r["head"], r["tail"])] = r["type"]
        net.add_edge(r["head"], r["tail"], title=r["type"], label=r["type"])

    scale=10 # Scaling the size of the nodes by 10*degree
    d = dict(G.degree)

    pos = nx.spring_layout(G)
    #Updating dict
    d.update((x, scale*y) for x, y in d.items())

    #Setting up size attribute
    nx.set_node_attributes(G,d,'size')
    nx.set_edge_attributes(G,labels, 'labels')
    # nx.draw_networkx_edge_labels(
    #                             G, pos,
    #                             edge_labels=labels,
    #                             # font_color='red'
    #                             )
    if verbose:
        print(f"Trying to make graph")

    # net.from_nx(G)   
    
    # save network
    if physics:
        net.repulsion(
            node_distance=200,
            central_gravity=0.3,
            spring_length=200,
            spring_strength=0.05,
            damping=0.09
        )

    net.set_edge_smooth('dynamic')

    if verbose:
        print(f"Trying to show graph")

    net.show(filename)

# %% [markdown]
# # --- BREAK ---

# %% [markdown]
# # EXP

# %% [markdown]
# ### LOAD MODEL

# %%
# Load model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("Babelscape/rebel-large")
model = AutoModelForSeq2SeqLM.from_pretrained("Babelscape/rebel-large")

# %%
model.to(get_gpu()[0])
# Out:
# BartForConditionalGeneration(
#   (model): BartModel(
#     (shared): Embedding(50272, 1024, padding_idx=1)
#     (encoder): BartEncoder(
#       (embed_tokens): Embedding(50272, 1024, padding_idx=1)
#       (embed_positions): BartLearnedPositionalEmbedding(1026, 1024)
#       (layers): ModuleList(
#         (0-11): 12 x BartEncoderLayer(
#           (self_attn): BartSdpaAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): BartDecoder(
#       (embed_tokens): Embedding(50272, 1024, padding_idx=1)
#       (embed_positions): BartLearnedPositionalEmbedding(1026, 1024)
#       (layers): ModuleList(
#         (0-11): 12 x BartDecoderLayer(
#           (self_attn): BartSdpaAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartSdpaAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (lm_head): Linear(in_features=1024, out_features=50272, bias=False)
# )

# %% [markdown]
# ### LOADING OFFLINE WIKI

# %%
WIKI_INDEX_FILE = "D://WikiDump/enwiki-20240220-pages-articles-multistream-index.txt/enwiki-20240220-pages-articles-multistream-index.txt"
WIKI_BZ2_FILE = "D://WikiDump/enwiki-20240220-pages-articles-multistream.xml.bz2"

INDEX_FOLDER = "./WikiDump_Search/indexes/"

# %%
offline_wikipedia = offline_Wiki(wiki_index_file=WIKI_INDEX_FILE,
                                wikiDump_bz2_file=WIKI_BZ2_FILE, verbose=True,
                                index_folder=INDEX_FOLDER)

# %%
# testing
print(offline_wikipedia.word_match("tigers", summaryOnly=False))
input()

test_words = ["sachin", "trump", "wedding", "white house", "modi", "apple", "windows 11"]
for test_word in test_words:
    print(offline_wikipedia.word_match(test_word))
# Out:
# {'title': 'Tigers', 'url': 'https://en.wikipedia.org/wiki/Tiger', 'summary': 'REDIRECT Tiger'}
# {'title': 'Sachin', 'url': 'https://en.wikipedia.org/wiki/Sachin', 'summary': 'Sachin may refer to:\nSachin (given name), an Indian given name, including a list of people with the name\n* Sachin (actor) (born 1957), Indian actor and filmmaker\n* Sachin (boxer), Indian boxer\n* Sachin Tendulkar (born 1973), Indian cricketer\n'}
# {'title': 'Trump', 'url': 'https://en.wikipedia.org/wiki/Trump', 'summary': 'Trump most commonly refers to:\nDonald Trump (born 1946), President of the United States from 2017 to 2021 \nTrump (card games), any playing card given an ad-hoc high rank\nTrump may also refer to:\n'}
# {'title': 'Wedding', 'url': 'https://en.wikipedia.org/wiki/Wedding', 'summary': 'A wedding is a ceremony where two people are united in marriage. Wedding traditions and customs vary greatly between cultures, ethnic groups, races, religions, denominations, countries, social classes, and sexual orientations. Most wedding ceremonies involve an exchange of marriage vows by a couple, presentation of a gift (offering, rings, symbolic item, flowers, money, dress), and a public proclamation of marriage by an authority figure or celebrant. Special wedding garments are often worn, and the ceremony is sometimes followed by a wedding reception. Music, poetry, prayers, or readings from religious texts or literature are also commonly incorporated into the ceremony, as well as superstitious customs.\n'}
# {'title': 'White House', 'url': 'https://en.wikipedia.org/wiki/White_House', 'summary': 'The White House is the official residence and workplace of the president of the United States. It is located at 1600 Pennsylvania Avenue NW in Washington, D.C., and has been the residence of every U.S. president since John Adams in 1800 when the national capital was moved from Philadelphia. The term "White House" is often used as metonymy for the president and his advisers.\nThe residence was designed by Irish-born architect James Hoban in the Neoclassical style. Hoban modeled the building on Leinster House in Dublin, a building which today houses the Oireachtas, the Irish legislature. Construction took place between 1792 and 1800, with an exterior of Aquia Creek sandstone painted white. When Thomas Jefferson moved into the house in 1801, he and architect Benjamin Henry Latrobe added low colonnades on each wing to conceal what then were stables and storage. In 1814, during the War of 1812, the mansion was set ablaze by British forces in the burning of Washington, destroying the interior and charring much of the exterior. Reconstruction began almost immediately, and President James Monroe moved into the partially reconstructed Executive Residence in October 1817. Exterior construction continued with the addition of the semicircular South Portico in 1824 and the North Portico in 1829.\nBecause of crowding within the executive mansion itself, President Theodore Roosevelt had all work offices relocated to the newly constructed West Wing in 1901. Eight years later, in 1909, President William Howard Taft expanded the West Wing and created the first Oval Office, which was eventually moved and expanded. In the Executive Residence, the third floor attic was converted to living quarters in 1927 by augmenting the existing [roof] with long shed dormers. A newly constructed East Wing was used as a reception area for social events; Jefferson\'s colonnades connected the new wings. The East Wing alterations were completed in 1946, creating additional office space. By 1948, the residence\'s load-bearing walls and wood beams were found to be close to failure. Under Harry S. Truman, the interior rooms were completely dismantled and a new internal load-bearing steel frame was constructed inside the walls. On the exterior, the Truman Balcony was added. Once the structural work was completed, the interior rooms were rebuilt.\nThe present-day White House complex includes the Executive Residence, the West Wing, the East Wing, the Eisenhower Executive Office Building, which previously served the State Department and other departments (it now houses additional offices for the president\'s staff and the vice president), and Blair House, a guest residence. The Executive Residence is made up of six stories: the Ground Floor, State Floor, Second Floor, and Third Floor, and a two-story basement. The property is a National Heritage Site owned by the National Park Service and is part of the President\'s Park. In 2007, it was ranked second on the American Institute of Architects list of America\'s Favorite Architecture.\n'}
# {'title': 'Modi', 'url': 'https://en.wikipedia.org/wiki/Narendra_Modi', 'summary': 'REDIRECT Narendra Modi'}
# {'title': 'Apple', 'url': 'https://en.wikipedia.org/wiki/Apple', 'summary': "An apple is a round, edible fruit produced by an apple tree (Malus spp., among them the domestic or orchard apple; Malus domestica). Apple trees are cultivated worldwide and are the most widely grown species in the genus Malus. The tree originated in Central Asia, where its wild ancestor, Malus sieversii, is still found. Apples have been grown for thousands of years in Asia and Europe and were introduced to North America by European colonists. Apples have religious and mythological significance in many cultures, including Norse, Greek, and European Christian tradition.\nApples grown from seed tend to be very different from those of their parents, and the resultant fruit frequently lacks desired characteristics. For commercial purposes, including botanical evaluation, apple cultivars are propagated by clonal grafting onto rootstocks. Apple trees grown without rootstocks tend to be larger and much slower to fruit after planting. Rootstocks are used to control the speed of growth and the size of the resulting tree, allowing for easier harvesting.\nThere are more than 7,500 cultivars of apples. Different cultivars are bred for various tastes and uses, including cooking, eating raw, and cider or apple juice production. Trees and fruit are prone to fungal, bacterial, and pest problems, which can be controlled by a number of organic and non-organic means. In 2010, the fruit's genome was sequenced as part of research on disease control and selective breeding in apple production.\nWorldwide production of apples in 2021 was 93 million tonnes, with China accounting for nearly half of the total.\n"}
# {'title': 'Windows 11', 'url': 'https://en.wikipedia.org/wiki/Windows_11', 'summary': 'Windows 11 is the latest major release of Microsoft\'s Windows NT operating system, released on October 5, 2021. It succeeded Windows 10 (2015) and is available for free for any Windows 10 devices that meet the new Windows 11 system requirements.\nWindows 11 features major changes to the Windows shell influenced by the canceled Windows 10X, including a redesigned Start menu, the replacement of its "live tiles" with a separate "Widgets" panel on the taskbar, the ability to create tiled sets of windows that can be minimized and restored from the taskbar as a group, and new gaming technologies inherited from Xbox Series X and Series S such as [video|Auto HDR] and DirectStorage on compatible hardware. Internet Explorer (IE) has been replaced by the Chromium-based Microsoft Edge as the default web browser, like its predecessor, Windows 10, and Microsoft Teams is integrated into the Windows shell. Microsoft also announced plans to allow more flexibility in software that can be distributed via the Microsoft Store and to support Android apps on Windows 11 (including a partnership with Amazon to make its app store available for the function).\nCiting security considerations, the system requirements for Windows 11 were increased over Windows 10. Microsoft only officially supports the operating system on devices using an eighth-generation Intel Core CPU or newer (with some minor exceptions), a second-generation AMD Ryzen CPU or newer, or a Qualcomm Snapdragon 850 ARM system-on-chip or newer, with UEFI and Trusted Platform Module (TPM) 2.0 supported and enabled (although Microsoft may provide exceptions to the TPM 2.0 requirement for OEMs). While the OS can be installed on unsupported processors, Microsoft does not guarantee the availability of updates. Windows 11 removed support for 32-bit x86 and 32-bit ARM CPUs and devices that use BIOS firmware.\nWindows 11 has received a mostly positive reception. Pre-release coverage of the operating system focused on its stricter hardware requirements, with discussions over whether they were legitimately intended to improve the security of Windows or as a ploy to upsell customers to newer devices and over the e-waste associated with the changes. Upon release, it was praised for its improved visual design, window management, and stronger focus on security, but was criticized for various modifications to aspects of its user interface that were seen as worse than its predecessor; some were seen as an attempt to dissuade users from switching to competing applications.\n, Windows 11, at 27% worldwide, is the second most popular Windows version in use, with its predecessor Windows 10 at 2.5 times the market share. Windows 11 has an estimated  19.75% share of all PCs (the rest being other Windows editions and other operating systems such as macOS and Linux), and an estimated  7.8% share of all devices (including mobile, tablet and console) are running Windows 11.\nTo comply with the Digital Markets Act, Microsoft is allowing users in the European Union to remove the Edge browser, Bing search engine, and advertisements to comply with users\' interests.\n'}

# %% [markdown]
# ## LIAR

# %%
store_folder = "./LIAR_data/"
statements_file = "./statements.json"

# %%
data_filepath = loadFILE(store_folder+statements_file)

# %% [markdown]
# ##### FOR FAKE DATA (INTERMEDIATE)

# %%
countt = 0
for d_text in data_filepath["fake"]:
    print(" ".join(clean_document(d_text)))
    if countt > 5:
        break
    print()
    countt+=1
# Out:
# The things I said during the prank call by a blogger posing as GOP contributor David Koch are the things Ive said publicly all along about the Wisconsin budget debate.
#
# They delayed my swearing-in here in Massachusetts for a couple weeks so they could ram the health care law through.
#
# 1 percent of candidates that the National Rifle Association endorsed in 2012 won.
#
# Were the most highly taxed nation in the world.
#
# I have voted every year in Wisconsin.
#
# Obama "remains silent" and "is never asked how he feels about his church honoring Farrakhan."
#
# Barack Hussein Obama will force doctors to assist homosexuals in buying surrogate babies.

# %%
texts = []
_data = data_filepath["fake"]
articles_limit = 3542
# articles_limit = int(input(f"enter number of docs to take (max : {len(_data)}): "))
print(f"taking {articles_limit} docs in KG")

countt = 0
for d_text in _data:
    _txt = " ".join(clean_document(d_text))
    # if len(_txt.split()) > 2000:
    #     continue
    texts.append(_txt)
    countt += 1
    if countt > articles_limit:
        break
# Out:
# taking 3542 docs in KG

# %%
len(texts)
# Out:
# 3541

# %%
max_lenn = 1000
spann = 64

# %%
kb = KB()
max_lenn = 1000
for text in tqdm(texts):
    # print(len(text.split()))
    # print(text)
    kb = from_text_to_kb(text, "", kb = kb,
                         useGPU = 1, 
                         verbose = 0, 
                         span_length = spann, 
                         max_doc_text = max_lenn,
                         useWiki = 0,                       # KEEPING IT 0, AS FOR NOW WE ONLY NEED THE POSSIBLE ENTITIES
                         offlineWiki = offline_wikipedia)
    # kb.print()
    # input()
# Out:
# 100%|██████████| 3541/3541 [17:54<00:00,  3.30it/s]

# %%
len(kb.entities), kb.print()
# Out:
# Entities:
#   ('David Koch', {'url': '', 'summary': ''})
#   ('GOP', {'url': '', 'summary': ''})
#   ('Wisconsin budget debate', {'url': '', 'summary': ''})
#   ('ram the health care law through', {'url': '', 'summary': ''})
#   ('Massachusetts', {'url': '', 'summary': ''})
#   ('health care law', {'url': '', 'summary': ''})
#   ('2012', {'url': '', 'summary': ''})
#   ('National Rifle Association endorsed in 2012', {'url': '', 'summary': ''})
#   ('National Rifle Association', {'url': '', 'summary': ''})
#   ('tax', {'url': '', 'summary': ''})
#   ('nation', {'url': '', 'summary': ''})
#   ('most highly taxed nation', {'url': '', 'summary': ''})
#   ('world', {'url': '', 'summary': ''})
#   ('voted every year', {'url': '', 'summary': ''})
#   ('Wisconsin', {'url': '', 'summary': ''})
#   ('every year', {'url': '', 'summary': ''})
#   ('state', {'url': '', 'summary': ''})
#   ('his church honoring Farrakhan', {'url': '', 'summary': ''})
#   ('Obama', {'url': '', 'summary': ''})
#   ('his church', {'url': '', 'summary': ''})
#   ('Barack Hussein Obama', {'url': '', 'summary': ''})
#   ('homosexuals', {'url': '', 'summary': ''})
#   ('Switzerland', {'url': '', 'summary': ''})
#   ('similar population', {'url': '', 'summary': ''})
#   ('Honduras', {'url': '', 'summary': ''})
#   ('Koch Industries', {'url': '', 'summary': ''})
#   ('Styrofoam', {'url': '', 'summary': ''})
#   ('Styrofoam cups', {'url': '', 'summary': ''})
#   ('CH2M Hill', {'url': '', 'summary': ''})
#   ('cryptosporidium', {'url': '', 'summary': ''})
#   ('cure', {'url': '', 'summary': ''})
#   ('cure us from cryptosporidium', {'url': '', 'summary': ''})
#   ('George W. Bush', {'url': '', 'summary': ''})
#   ('President', {'url': '', 'summary': ''})
#   ('the governor', {'url': '', 'summary': ''})
#   ('George Allen', {'url': '', 'summary': ''})
#   ('Eric Cantor', {'url': '', 'summary': ''})
#   ('immigration reform', {'url': '', 'summary': ''})
#   ('Luis Gutierrez', {'url': '', 'summary': ''})
#   ('Immigration reform', {'url': '', 'summary': ''})
#   ('new state budget', {'url': '', 'summary': ''})
#   ('Floridians', {'url': '', 'summary': ''})
#   ('state budget', {'url': '', 'summary': ''})
#   ('Florida', {'url': '', 'summary': ''})
#   ('2006', {'url': '', 'summary': ''})
#   ('2013', {'url': '', 'summary': ''})
#   ('Planned Parenthood', {'url': '', 'summary': ''})
#   ('abortion', {'url': '', 'summary': ''})
#   ('mental health facility', {'url': '', 'summary': ''})
#   ('Milwaukee County', {'url': '', 'summary': ''})
#   ('Milwaukee', {'url': '', 'summary': ''})
#   ('Barack Obama', {'url': '', 'summary': ''})
#   ('candidate', {'url': '', 'summary': ''})
#   ('then candidate', {'url': '', 'summary': ''})
#   ('I Was Paid 3,500 To Protest Trumps Rally', {'url': '', 'summary': ''})
#   ('Donald Trump Protester Speaks Out', {'url': '', 'summary': ''})
#   ('Donald Trump Protester Speaks Out I Was Paid 3,500 To Protest Trumps Rally.', {'url': '', 'summary': ''})
#   ('Donald Trump Protester Speaks Out I Was Paid 3,500 To Protest Trumps Rally', {'url': '', 'summary': ''})
#   ('refinanced', {'url': '', 'summary': ''})
#   ('student loan', {'url': '', 'summary': ''})
#   ('student loans', {'url': '', 'summary': ''})
#   ('On reconciliation', {'url': '', 'summary': ''})
#   ('reconciliation', {'url': '', 'summary': ''})
#   ('Medicaid', {'url': '', 'summary': ''})
#   ('Democrats', {'url': '', 'summary': ''})
#   ('Republicans', {'url': '', 'summary': ''})
#   ('Benghazi attacks', {'url': '', 'summary': ''})
#   ('White House', {'url': '', 'summary': ''})
#   ('White House had a live video feed', {'url': '', 'summary': ''})
#   ('live video feed', {'url': '', 'summary': ''})
#   ('game here', {'url': '', 'summary': ''})
#   ('Pittsburgh Steelers', {'url': '', 'summary': ''})
#   ('23', {'url': '', 'summary': ''})
#   ('1972', {'url': '', 'summary': ''})
#   ('defund ObamaCare', {'url': '', 'summary': ''})
#   ('defund', {'url': '', 'summary': ''})
#   ('ObamaCare', {'url': '', 'summary': ''})
#   ('Rhode Island', {'url': '', 'summary': ''})
#   ('people', {'url': '', 'summary': ''})
#   ('dont want same-sex marriage', {'url': '', 'summary': ''})
#   ('people of Rhode Island', {'url': '', 'summary': ''})
#   ('Maggie Hassan', {'url': '', 'summary': ''})
#   ('governor', {'url': '', 'summary': ''})
#   ('ACORN', {'url': '', 'summary': ''})
#   ('Bertha Lewis', {'url': '', 'summary': ''})
#   ('Ronald Reagan', {'url': '', 'summary': ''})
#   ('fired the air traffic controllers', {'url': '', 'summary': ''})
#   ('Reagan fired the air traffic controllers', {'url': '', 'summary': ''})
#   ('rape', {'url': '', 'summary': ''})
#   ('pregnancy', {'url': '', 'summary': ''})
#   ('womans body', {'url': '', 'summary': ''})
#   ('Central', {'url': '', 'summary': ''})
#   ('education protest', {'url': '', 'summary': ''})
#   ('Central Florida', {'url': '', 'summary': ''})
#   ('cost-of-living increase in Social Security', {'url': '', 'summary': ''})
#   ('wage inflation', {'url': '', 'summary': ''})
#   ('cost-of-living increase', {'url': '', 'summary': ''})
#   ('Social Security', {'url': '', 'summary': ''})
#   ('obesity rates', {'url': '', 'summary': ''})
#   ('1980', {'url': '', 'summary': ''})
#   ('obesity rates that existed back in the 1980s', {'url': '', 'summary': ''})
#   ('obesity', {'url': '', 'summary': ''})
#   ('prosecutorial discretion', {'url': '', 'summary': ''})
#   ('immigration', {'url': '', 'summary': ''})
#   ('immigration case', {'url': '', 'summary': ''})
#   ('federal worker', {'url': '', 'summary': ''})
#   ('private sector worker', {'url': '', 'summary': ''})
#   ('Christian daycare', {'url': '', 'summary': ''})
#   ('Christian', {'url': '', 'summary': ''})
#   ('religious freedom', {'url': '', 'summary': ''})
#   ('rights', {'url': '', 'summary': ''})
#   ('Iran', {'url': '', 'summary': ''})
#   ('superpower', {'url': '', 'summary': ''})
#   ('America', {'url': '', 'summary': ''})
#   ('Barack Obamas', {'url': '', 'summary': ''})
#   ('Stephen Sweeney', {'url': '', 'summary': ''})
#   ('state Senate President', {'url': '', 'summary': ''})
#   ('Senate President', {'url': '', 'summary': ''})
#   ('bin Laden', {'url': '', 'summary': ''})
#   ('David Dewhursts', {'url': '', 'summary': ''})
#   ('Texas Senate', {'url': '', 'summary': ''})
#   ('Nobodys', {'url': '', 'summary': ''})
#   ('Fox News', {'url': '', 'summary': ''})
#   ('childrens hospital', {'url': '', 'summary': ''})
#   ('hospital', {'url': '', 'summary': ''})
#   ('hospitals', {'url': '', 'summary': ''})
#   ('childrens hospitals', {'url': '', 'summary': ''})
#   ('Bush', {'url': '', 'summary': ''})
#   ('Bush was', {'url': '', 'summary': ''})
#   ('trying to control North Korea', {'url': '', 'summary': ''})
#   ('Kurt Browning', {'url': '', 'summary': ''})
#   ('Florida secretary of state', {'url': '', 'summary': ''})
#   ('Pakistan', {'url': '', 'summary': ''})
#   ('Afghanistan', {'url': '', 'summary': ''})
#   ('Syria', {'url': '', 'summary': ''})
#   ('double-layered border fencing', {'url': '', 'summary': ''})
#   ('Mexico border', {'url': '', 'summary': ''})
#   ('double-layered', {'url': '', 'summary': ''})
#   ('border fencing', {'url': '', 'summary': ''})
#   ('Repealing and replacing', {'url': '', 'summary': ''})
#   ('Obamacare', {'url': '', 'summary': ''})
#   ('Repealing and replacing Obamacare', {'url': '', 'summary': ''})
#   ('10', {'url': '', 'summary': ''})
#   ('abortion clinic', {'url': '', 'summary': ''})
#   ('Bill White', {'url': '', 'summary': ''})
#   ('SAVE database', {'url': '', 'summary': ''})
#   ('Department of Homeland Security', {'url': '', 'summary': ''})
#   ('SAVE', {'url': '', 'summary': ''})
#   ('Christopher Little', {'url': '', 'summary': ''})
#   ('environmental protection', {'url': '', 'summary': ''})
#   ('polluters', {'url': '', 'summary': ''})
#   ('fourth-poorest congressional district', {'url': '', 'summary': ''})
#   ('fourth-poorest', {'url': '', 'summary': ''})
#   ('congressional district', {'url': '', 'summary': ''})
#   ('the fourth-poorest congressional district', {'url': '', 'summary': ''})
#   ('Scott Walkers', {'url': '', 'summary': ''})
#   ('Wisconsin Gov.', {'url': '', 'summary': ''})
#   ('Gov. Scott Walkers', {'url': '', 'summary': ''})
#   ('cuts funding for veterans by 24 percent', {'url': '', 'summary': ''})
#   ('Paul Ryan', {'url': '', 'summary': ''})
#   ('cutting funding for veterans by 24 percent', {'url': '', 'summary': ''})
#   ('same-sex marriage', {'url': '', 'summary': ''})
#   ('On same-sex marriage', {'url': '', 'summary': ''})
#   ('increase taxes', {'url': '', 'summary': ''})
#   ('IRS', {'url': '', 'summary': ''})
#   ('health care marketplace', {'url': '', 'summary': ''})
#   ('privacy protections', {'url': '', 'summary': ''})
#   ('health care marketplaces', {'url': '', 'summary': ''})
#   ('Rihanna', {'url': '', 'summary': ''})
#   ('stand your ground', {'url': '', 'summary': ''})
#   ('Donald Sterling', {'url': '', 'summary': ''})
#   ('Democrat', {'url': '', 'summary': ''})
#   ('Los Angeles Clippers', {'url': '', 'summary': ''})
#   ('2002', {'url': '', 'summary': ''})
#   ('public school funding', {'url': '', 'summary': ''})
#   ('Texas', {'url': '', 'summary': ''})
#   ('fluorescent light bulbs', {'url': '', 'summary': ''})
#   ('light bulbs', {'url': '', 'summary': ''})
#   ('light bulb', {'url': '', 'summary': ''})
#   ('fluorescent light bulb', {'url': '', 'summary': ''})
#   ('United States', {'url': '', 'summary': ''})
#   ('Interpol', {'url': '', 'summary': ''})
#   ('Obama executive order', {'url': '', 'summary': ''})
#   ('international pressure', {'url': '', 'summary': ''})
#   ('pressure', {'url': '', 'summary': ''})
#   ('2012 re-election campaigns', {'url': '', 'summary': ''})
#   ('2012 re-election campaign', {'url': '', 'summary': ''})
#   ('single-occupancy vehicle', {'url': '', 'summary': ''})
#   ('vehicle', {'url': '', 'summary': ''})
#   ('vehicles', {'url': '', 'summary': ''})
#   ('Texas Department of Transportation', {'url': '', 'summary': ''})
#   ('Sandy Adams', {'url': '', 'summary': ''})
#   ('stimulus spending', {'url': '', 'summary': ''})
#   ('iPad', {'url': '', 'summary': ''})
#   ('United States of America', {'url': '', 'summary': ''})
#   ('iPhone', {'url': '', 'summary': ''})
#   ('Nevada', {'url': '', 'summary': ''})
#   ('white', {'url': '', 'summary': ''})
#   ('80 percent white voters', {'url': '', 'summary': ''})
#   ('roads', {'url': '', 'summary': ''})
#   ('road', {'url': '', 'summary': ''})
#   ('Fix Our Roads', {'url': '', 'summary': ''})
#   ('2008', {'url': '', 'summary': ''})
#   ('Republican', {'url': '', 'summary': ''})
#   ('clinical evidence', {'url': '', 'summary': ''})
#   ('vaccine', {'url': '', 'summary': ''})
#   ('protects patients', {'url': '', 'summary': ''})
#   ('Obamas Environmental Protection Agency', {'url': '', 'summary': ''})
#   ('Environmental Protection Agency', {'url': '', 'summary': ''})
#   ('Back door gun control', {'url': '', 'summary': ''})
#   ('last census', {'url': '', 'summary': ''})
#   ('audit of the last census', {'url': '', 'summary': ''})
#   ('the last census', {'url': '', 'summary': ''})
#   ('Charlie Crist', {'url': '', 'summary': ''})
#   ('I got elected', {'url': '', 'summary': ''})
#   ('deficit', {'url': '', 'summary': ''})
#   ('U.S.', {'url': '', 'summary': ''})
#   ('2009', {'url': '', 'summary': ''})
#   ('2009 World Cup', {'url': '', 'summary': ''})
#   ('father', {'url': '', 'summary': ''})
#   ('cat', {'url': '', 'summary': ''})
#   ('mother', {'url': '', 'summary': ''})
#   ('refugees', {'url': '', 'summary': ''})
#   ('migrants', {'url': '', 'summary': ''})
#   ('Syrian refugees', {'url': '', 'summary': ''})
#   ('refugee', {'url': '', 'summary': ''})
#   ('2012 election', {'url': '', 'summary': ''})
#   ('University of California, Berkeley', {'url': '', 'summary': ''})
#   ('Berkeley, California', {'url': '', 'summary': ''})
#   ('Dawn Johnsen', {'url': '', 'summary': ''})
#   ('Obama nominee', {'url': '', 'summary': ''})
#   ('Centers for Medicare and Medicaid Services', {'url': '', 'summary': ''})
#   ('Medicaid waiver', {'url': '', 'summary': ''})
#   ('Sheila Jackson Lee', {'url': '', 'summary': ''})
#   ('state parks', {'url': '', 'summary': ''})
#   ('Oregon', {'url': '', 'summary': ''})
#   ('state park', {'url': '', 'summary': ''})
#   ('watersheds', {'url': '', 'summary': ''})
#   ('threatened to bomb Pakistan', {'url': '', 'summary': ''})
#   ('redistricting', {'url': '', 'summary': ''})
#   ('lawsuits', {'url': '', 'summary': ''})
#   ('2010 election', {'url': '', 'summary': ''})
#   ('2010', {'url': '', 'summary': ''})
#   ('Ferguson', {'url': '', 'summary': ''})
#   ('Mo', {'url': '', 'summary': ''})
#   ('Ferguson, Mo.', {'url': '', 'summary': ''})
#   ('over a decade now', {'url': '', 'summary': ''})
#   ('net global warming', {'url': '', 'summary': ''})
#   ('decade now', {'url': '', 'summary': ''})
#   ('no net global warming', {'url': '', 'summary': ''})
#   ('Rick Scott', {'url': '', 'summary': ''})
#   ('Governor', {'url': '', 'summary': ''})
#   ('destroyed over 100,000 jobs', {'url': '', 'summary': ''})
#   ('Common Core', {'url': '', 'summary': ''})
#   ('State Standards', {'url': '', 'summary': ''})
#   ('Common Core State Standards', {'url': '', 'summary': ''})
#   ('Teachers', {'url': '', 'summary': ''})
#   ('slush fund', {'url': '', 'summary': ''})
#   ('treasury secretary', {'url': '', 'summary': ''})
#   ('50', {'url': '', 'summary': ''})
#   ('Marco Rubio', {'url': '', 'summary': ''})
#   ('rowing', {'url': '', 'summary': ''})
#   ('cars.gov', {'url': '', 'summary': ''})
#   ('Web site', {'url': '', 'summary': ''})
#   ('Cash for Clunkers', {'url': '', 'summary': ''})
#   ('JoAnne Kloppenburg', {'url': '', 'summary': ''})
#   ('Wisconsin Supreme Court', {'url': '', 'summary': ''})
#   ('JoAnne Kloppenburgs', {'url': '', 'summary': ''})
#   ('Martin Luther King Jr.', {'url': '', 'summary': ''})
#   ('Martin Luther King Jr', {'url': '', 'summary': ''})
#   ('health insurance', {'url': '', 'summary': ''})
#   ('insurance', {'url': '', 'summary': ''})
#   ('health care decisions', {'url': '', 'summary': ''})
#   ('Americans', {'url': '', 'summary': ''})
#   ('major health care decisions', {'url': '', 'summary': ''})
#   ('state contractors', {'url': '', 'summary': ''})
#   ('construction', {'url': '', 'summary': ''})
#   ('Majority Leader', {'url': '', 'summary': ''})
#   ('Josef Stalin', {'url': '', 'summary': ''})
#   ('Soviet dictator', {'url': '', 'summary': ''})
#   ('Franklin Delano Roosevelt', {'url': '', 'summary': ''})
#   ('Soviet', {'url': '', 'summary': ''})
#   ('MarkKirk', {'url': '', 'summary': ''})
#   ('African Americans', {'url': '', 'summary': ''})
#   ('mass arrest of 18,000 African Americans', {'url': '', 'summary': ''})
#   ('mass deportation', {'url': '', 'summary': ''})
#   ('Islamic State', {'url': '', 'summary': ''})
#   ('for-profit', {'url': '', 'summary': ''})
#   ('medical school', {'url': '', 'summary': ''})
#   ('medical schools', {'url': '', 'summary': ''})
#   ('Congresswoman Louise Slaughter', {'url': '', 'summary': ''})
#   ('Congressman Tom Reed', {'url': '', 'summary': ''})
#   ('Tom Reed', {'url': '', 'summary': ''})
#   ('Congressman', {'url': '', 'summary': ''})
#   ('President Obama', {'url': '', 'summary': ''})
#   ('federal government', {'url': '', 'summary': ''})
#   ('Columbia University', {'url': '', 'summary': ''})
#   ('Barry Soetoro', {'url': '', 'summary': ''})
#   ('constitutional rulings', {'url': '', 'summary': ''})
#   ('Supreme Court', {'url': '', 'summary': ''})
#   ('constitutional', {'url': '', 'summary': ''})
#   ('Foreign Intelligence Surveillance Court', {'url': '', 'summary': ''})
#   ('transparent', {'url': '', 'summary': ''})
#   ('healthcare takeover', {'url': '', 'summary': ''})
#   ('Medicare', {'url': '', 'summary': ''})
#   ('big-government healthcare takeover', {'url': '', 'summary': ''})
#   ('TARP', {'url': '', 'summary': ''})
#   ('Mitt Romney', {'url': '', 'summary': ''})
#   ('supporting the TARP program', {'url': '', 'summary': ''})
#   ('doctor', {'url': '', 'summary': ''})
#   ('profession', {'url': '', 'summary': ''})
#   ('psychiatrist', {'url': '', 'summary': ''})
#   ('physician', {'url': '', 'summary': ''})
#   ('doctors', {'url': '', 'summary': ''})
#   ('Federal Aviation Administration', {'url': '', 'summary': ''})
#   ('FAA', {'url': '', 'summary': ''})
#   ('President of the United States', {'url': '', 'summary': ''})
#   ('fiscal year 2012', {'url': '', 'summary': ''})
#   ('earmarks in fiscal year 2012', {'url': '', 'summary': ''})
#   ('Herman Cain', {'url': '', 'summary': ''})
#   ('pro-choice', {'url': '', 'summary': ''})
#   ('health care overhaul', {'url': '', 'summary': ''})
#   ('Internal Revenue Service', {'url': '', 'summary': ''})
#   ('federal health care overhaul', {'url': '', 'summary': ''})
#   ('federal', {'url': '', 'summary': ''})
#   ('John F. Kennedy School of Government', {'url': '', 'summary': ''})
#   ('Harvard University', {'url': '', 'summary': ''})
#   ('John F. Kennedy', {'url': '', 'summary': ''})
#   ('military veterans', {'url': '', 'summary': ''})
#   ('this country', {'url': '', 'summary': ''})
#   ('veterans', {'url': '', 'summary': ''})
#   ('military', {'url': '', 'summary': ''})
#   ('Veterans Day', {'url': '', 'summary': ''})
#   ('Memorial Day', {'url': '', 'summary': ''})
#   ('employer subsidy', {'url': '', 'summary': ''})
#   ('exchange', {'url': '', 'summary': ''})
#   ('economic recovery', {'url': '', 'summary': ''})
#   ('worst economic recovery America has ever had', {'url': '', 'summary': ''})
#   ('economic recovery America has ever had', {'url': '', 'summary': ''})
#   ('John Boccieris', {'url': '', 'summary': ''})
#   ('Rep.', {'url': '', 'summary': ''})
#   ('unemployment', {'url': '', 'summary': ''})
#   ('Ohio', {'url': '', 'summary': ''})
#   ('Affordable Care Act', {'url': '', 'summary': ''})
#   ('76', {'url': '', 'summary': ''})
#   ('Part D', {'url': '', 'summary': ''})
#   ('Barack Obama was born', {'url': '', 'summary': ''})
#   ('Barack Obama was born in the United States', {'url': '', 'summary': ''})
#   ('Obama stimulus', {'url': '', 'summary': ''})
#   ('Obama stimulus dollars', {'url': '', 'summary': ''})
#   ('Ryan Sittons', {'url': '', 'summary': ''})
#   ('Joseph Stalin', {'url': '', 'summary': ''})
#   ('patriotism', {'url': '', 'summary': ''})
#   ('morality', {'url': '', 'summary': ''})
#   ('Scott Walker', {'url': '', 'summary': ''})
#   ('Milwaukees', {'url': '', 'summary': ''})
#   ('black', {'url': '', 'summary': ''})
#   ('public education', {'url': '', 'summary': ''})
#   ('Virginia', {'url': '', 'summary': ''})
#   ('education', {'url': '', 'summary': ''})
#   ('voters do NOT support hunting', {'url': '', 'summary': ''})
#   ('NJ', {'url': '', 'summary': ''})
#   ('voters', {'url': '', 'summary': ''})
#   ('Dane', {'url': '', 'summary': ''})
#   ('2016 presidential recount', {'url': '', 'summary': ''})
#   ('2016', {'url': '', 'summary': ''})
#   ('John Doe', {'url': '', 'summary': ''})
#   ('criminal investigation', {'url': '', 'summary': ''})
#   ('criminal investigation of his campaign', {'url': '', 'summary': ''})
#   ('campaign', {'url': '', 'summary': ''})
#   ('New Jersey', {'url': '', 'summary': ''})
#   ('California', {'url': '', 'summary': ''})
#   ('Illinois', {'url': '', 'summary': ''})
#   ('2011-13 state budget', {'url': '', 'summary': ''})
#   ('2011', {'url': '', 'summary': ''})
#   ('2011-13', {'url': '', 'summary': ''})
#   ('50 states', {'url': '', 'summary': ''})
#   ('Department of Justice', {'url': '', 'summary': ''})
#   ('website', {'url': '', 'summary': ''})
#   ('Gov.', {'url': '', 'summary': ''})
#   ('2008 election', {'url': '', 'summary': ''})
#   ('Jon Runyan', {'url': '', 'summary': ''})
#   ('voted to end programs to aid homeless veterans', {'url': '', 'summary': ''})
#   ('voted to end programs to aid homeless veterans.', {'url': '', 'summary': ''})
#   ('Wisconsins', {'url': '', 'summary': ''})
#   ('illegal immigrants in the United States', {'url': '', 'summary': ''})
#   ('30 million', {'url': '', 'summary': ''})
#   ('illegal immigrants', {'url': '', 'summary': ''})
#   ('surgeon general', {'url': '', 'summary': ''})
#   ('anti-gun activist', {'url': '', 'summary': ''})
#   ('Ted Cruz', {'url': '', 'summary': ''})
#   ('his father', {'url': '', 'summary': ''})
#   ('photographedwith Lee Harvey Oswald', {'url': '', 'summary': ''})
#   ('governor of Massachusetts', {'url': '', 'summary': ''})
#   ('solar panel', {'url': '', 'summary': ''})
#   ('energy', {'url': '', 'summary': ''})
#   ('legalizing same-sex marriage', {'url': '', 'summary': ''})
#   ('Poll', {'url': '', 'summary': ''})
#   ('Polls on legalizing same-sex marriage', {'url': '', 'summary': ''})
#   ('Polling on legalizing same-sex marriage', {'url': '', 'summary': ''})
#   ('Reagan', {'url': '', 'summary': ''})
#   ('top 1 percent', {'url': '', 'summary': ''})
#   ('top 1 percent pay', {'url': '', 'summary': ''})
#   ('top 1 percent pay over half of the entire revenue for this country', {'url': '', 'summary': ''})
#   ('states', {'url': '', 'summary': ''})
#   ('union states', {'url': '', 'summary': ''})
#   ('forced union states', {'url': '', 'summary': ''})
#   ('pat-down', {'url': '', 'summary': ''})
#   ('airport security', {'url': '', 'summary': ''})
#   ('David Dewhurst', {'url': '', 'summary': ''})
#   ('John Cornyn', {'url': '', 'summary': ''})
#   ('U.S. Senate', {'url': '', 'summary': ''})
#   ('7 billion to bring electricity to Africa', {'url': '', 'summary': ''})
#   ('spent 7 billion to bring electricity to Africa', {'url': '', 'summary': ''})
#   ('failed miserably', {'url': '', 'summary': ''})
#   ('Kenya', {'url': '', 'summary': ''})
#   ('universal health care plan', {'url': '', 'summary': ''})
#   ('universal', {'url': '', 'summary': ''})
#   ('presidential candidate', {'url': '', 'summary': ''})
#   ('military intervention in Syria', {'url': '', 'summary': ''})
#   ('Florida primary', {'url': '', 'summary': ''})
#   ('Jeb Bush', {'url': '', 'summary': ''})
#   ('national budget', {'url': '', 'summary': ''})
#   ('Japan', {'url': '', 'summary': ''})
#   ('Japans', {'url': '', 'summary': ''})
#   ('its national budget', {'url': '', 'summary': ''})
#   ('Medicare IRS', {'url': '', 'summary': ''})
#   ('health care reform law', {'url': '', 'summary': ''})
#   ('Congressional Progressive Caucus', {'url': '', 'summary': ''})
#   ('Communist Party', {'url': '', 'summary': ''})
#   ('amnesty', {'url': '', 'summary': ''})
#   ('illegally', {'url': '', 'summary': ''})
#   ('illegal', {'url': '', 'summary': ''})
#   ('allow people who are here illegally to be able to stay here', {'url': '', 'summary': ''})
#   ('small business', {'url': '', 'summary': ''})
#   ('job creators', {'url': '', 'summary': ''})
#   ('Carol Shea-Porter', {'url': '', 'summary': ''})
#   ('prison', {'url': '', 'summary': ''})
#   ('penitentiary', {'url': '', 'summary': ''})
#   ('ex-cons', {'url': '', 'summary': ''})
#   ('recidivism', {'url': '', 'summary': ''})
#   ("I'd Like to Teach the World to Sing", {'url': '', 'summary': ''})
#   ('national anthem', {'url': '', 'summary': ''})
#   ('"I\'d Like to Teach the World to Sing"', {'url': '', 'summary': ''})
#   ('bill', {'url': '', 'summary': ''})
#   ('Earl Blumenauer', {'url': '', 'summary': ''})
#   ('2014', {'url': '', 'summary': ''})
#   ('ending Medicare as we know it', {'url': '', 'summary': ''})
#   ('Hoover', {'url': '', 'summary': ''})
#   ('Presidents', {'url': '', 'summary': ''})
#   ('Truman', {'url': '', 'summary': ''})
#   ('Eisenhower', {'url': '', 'summary': ''})
#   ('average hourly wage', {'url': '', 'summary': ''})
#   ('General Motors', {'url': '', 'summary': ''})
#   ('General Motors Co.', {'url': '', 'summary': ''})
#   ('2008 presidential election', {'url': '', 'summary': ''})
#   ('Jim Langevin', {'url': '', 'summary': ''})
#   ('U.S. Rep.', {'url': '', 'summary': ''})
#   ('illegal immigration', {'url': '', 'summary': ''})
#   ('border fence', {'url': '', 'summary': ''})
#   ('rape kit', {'url': '', 'summary': ''})
#   ('rape victims', {'url': '', 'summary': ''})
#   ('rape victim', {'url': '', 'summary': ''})
#   ('Wendy Davis', {'url': '', 'summary': ''})
#   ('Democratic socialists', {'url': '', 'summary': ''})
#   ('Democratic socialists group', {'url': '', 'summary': ''})
#   ('Mickey Mouse', {'url': '', 'summary': ''})
#   ('Mickey Mouse was registered to vote in Florida', {'url': '', 'summary': ''})
#   ('abolish', {'url': '', 'summary': ''})
#   ('Second Amendment', {'url': '', 'summary': ''})
#   ('abolish the Second Amendment', {'url': '', 'summary': ''})
#   ('Hillary Clinton', {'url': '', 'summary': ''})
#   ('FEC report', {'url': '', 'summary': ''})
#   ('tax return', {'url': '', 'summary': ''})
#   ('stimulus money', {'url': '', 'summary': ''})
#   ('2009 election', {'url': '', 'summary': ''})
#   ('government', {'url': '', 'summary': ''})
#   ('poor', {'url': '', 'summary': ''})
#   ('state constitution', {'url': '', 'summary': ''})
#   ('Tennessee', {'url': '', 'summary': ''})
#   ('state income tax', {'url': '', 'summary': ''})
#   ('Houston National Cemetery', {'url': '', 'summary': ''})
#   ('military funerals', {'url': '', 'summary': ''})
#   ('Missouri', {'url': '', 'summary': ''})
#   ('protests', {'url': '', 'summary': ''})
#   ('2012 Democratic National Convention', {'url': '', 'summary': ''})
#   ('2008 Democratic National Convention', {'url': '', 'summary': ''})
#   ('cut Medicare', {'url': '', 'summary': ''})
#   ('Alex Sink', {'url': '', 'summary': ''})
#   ('Doug MacGinnitie', {'url': '', 'summary': ''})
#   ('income tax bracket', {'url': '', 'summary': ''})
#   ('Jan. 1, 2011', {'url': '', 'summary': ''})
#   ('income tax', {'url': '', 'summary': ''})
#   ('bracket', {'url': '', 'summary': ''})
#   ('health care reform', {'url': '', 'summary': ''})
#   ('health care costs', {'url': '', 'summary': ''})
#   ('Ken Hodges', {'url': '', 'summary': ''})
#   ('justice wasnt done in this case', {'url': '', 'summary': ''})
#   ('high-speed rail', {'url': '', 'summary': ''})
#   ('rail', {'url': '', 'summary': ''})
#   ('press secretary', {'url': '', 'summary': ''})
#   ('White House press secretary', {'url': '', 'summary': ''})
#   ('reporters', {'url': '', 'summary': ''})
#   ('Power Plan', {'url': '', 'summary': ''})
#   ('Obama administrations', {'url': '', 'summary': ''})
#   ('Electric Reliability Council of Texas', {'url': '', 'summary': ''})
#   ('state Senate candidate', {'url': '', 'summary': ''})
#   ('Aaron Bean', {'url': '', 'summary': ''})
#   ('state Senate', {'url': '', 'summary': ''})
#   ('Bill', {'url': '', 'summary': ''})
#   ('General Assembly', {'url': '', 'summary': ''})
#   ('session', {'url': '', 'summary': ''})
#   ('the abuse of prisoners', {'url': '', 'summary': ''})
#   ('photographs', {'url': '', 'summary': ''})
#   ('prisoners', {'url': '', 'summary': ''})
#   ('teacher', {'url': '', 'summary': ''})
#   ('salary', {'url': '', 'summary': ''})
#   ('school teacher', {'url': '', 'summary': ''})
#   ('cap-and-trade', {'url': '', 'summary': ''})
#   ('plan', {'url': '', 'summary': ''})
#   ('cap-and-trade plan', {'url': '', 'summary': ''})
#   ('2016 federal omnibus spending bill', {'url': '', 'summary': ''})
#   ('border', {'url': '', 'summary': ''})
#   ('ObamaCare enrollment lie', {'url': '', 'summary': ''})
#   ('ObamaCare enrollment lie Obama', {'url': '', 'summary': ''})
#   ('enrollee', {'url': '', 'summary': ''})
#   ('omnibus bill', {'url': '', 'summary': ''})
#   ('earmark', {'url': '', 'summary': ''})
#   ('earmarks', {'url': '', 'summary': ''})
#   ('Israel', {'url': '', 'summary': ''})
#   ('Iran deal', {'url': '', 'summary': ''})
#   ('censor the internet', {'url': '', 'summary': ''})
#   ('Sheldon Whitehouse', {'url': '', 'summary': ''})
#   ('voted to censor the internet', {'url': '', 'summary': ''})
#   ('Nikita Khrushchev', {'url': '', 'summary': ''})
#   ('United Nations', {'url': '', 'summary': ''})
#   ('1960', {'url': '', 'summary': ''})
#   ('work requirement', {'url': '', 'summary': ''})
#   ('welfare', {'url': '', 'summary': ''})
#   ('work requirement for welfare', {'url': '', 'summary': ''})
#   ('law', {'url': '', 'summary': ''})
#   ('Texas law', {'url': '', 'summary': ''})
#   ('law says that you cant shoot bears out of the second floor of a window', {'url': '', 'summary': ''})
#   ('earmark moratorium', {'url': '', 'summary': ''})
#   ('moratorium', {'url': '', 'summary': ''})
#   ('Libertarian Party', {'url': '', 'summary': ''})
#   ('political party', {'url': '', 'summary': ''})
#   ('China', {'url': '', 'summary': ''})
#   ('Russia', {'url': '', 'summary': ''})
#   ('Canadian', {'url': '', 'summary': ''})
#   ('Canadian-born', {'url': '', 'summary': ''})
#   ('Canada', {'url': '', 'summary': ''})
#   ('Barack Obamas birth certificate', {'url': '', 'summary': ''})
#   ('Kinkos', {'url': '', 'summary': ''})
#   ('Loretta Lynch', {'url': '', 'summary': ''})
#   ('attorney general', {'url': '', 'summary': ''})
#   ('Whitewater corruption probe', {'url': '', 'summary': ''})
#   ('Bill Clintons', {'url': '', 'summary': ''})
#   ('votes for legislation', {'url': '', 'summary': ''})
#   ('Constitution', {'url': '', 'summary': ''})
#   ('legislation', {'url': '', 'summary': ''})
#   ('Confederate battle flag', {'url': '', 'summary': ''})
#   ('property taxes', {'url': '', 'summary': ''})
#   ('November', {'url': '', 'summary': ''})
#   ('property tax', {'url': '', 'summary': ''})
#   ('Hillary', {'url': '', 'summary': ''})
#   ('Dems', {'url': '', 'summary': ''})
#   ('NFL', {'url': '', 'summary': ''})
#   ('2', {'url': '', 'summary': ''})
#   ('gold standard', {'url': '', 'summary': ''})
#   ('currency', {'url': '', 'summary': ''})
#   ('U.S. currency', {'url': '', 'summary': ''})
#   ('Blue Cross', {'url': '', 'summary': ''})
#   ('headquarters', {'url': '', 'summary': ''})
#   ('attacks on our natural resources', {'url': '', 'summary': ''})
#   ('Washington bureaucrats', {'url': '', 'summary': ''})
#   ('Washington', {'url': '', 'summary': ''})
#   ('able-bodied men', {'url': '', 'summary': ''})
#   ('John', {'url': '', 'summary': ''})
#   ('Senate', {'url': '', 'summary': ''})
#   ("John's", {'url': '', 'summary': ''})
#   ('2012 Obama won in every state that did not require a photo ID and lost in every state that did require a photo ID in order to vote', {'url': '', 'summary': ''})
#   ('Texas House speaker', {'url': '', 'summary': ''})
#   ('House speaker', {'url': '', 'summary': ''})
#   ('Speaker', {'url': '', 'summary': ''})
#   ('Texas House', {'url': '', 'summary': ''})
#   ('Congress', {'url': '', 'summary': ''})
#   ('American people', {'url': '', 'summary': ''})
#   ('George Bush', {'url': '', 'summary': ''})
#   ('Arctic National Wildlife Refuge', {'url': '', 'summary': ''})
#   ('wildlife', {'url': '', 'summary': ''})
#   ('no wildlife', {'url': '', 'summary': ''})
#   ('No wildlife', {'url': '', 'summary': ''})
#   ('I supported the surge', {'url': '', 'summary': ''})
#   ('surge', {'url': '', 'summary': ''})
#   ("I supported the surge when you didn't", {'url': '', 'summary': ''})
#   ('Bernie Sanders', {'url': '', 'summary': ''})
#   ('90 percent', {'url': '', 'summary': ''})
#   ('tax you people', {'url': '', 'summary': ''})
#   ('tax you people at 90 percent', {'url': '', 'summary': ''})
#   ('Benghazi', {'url': '', 'summary': ''})
#   ('Libya', {'url': '', 'summary': ''})
#   ('gubernatorial candidate', {'url': '', 'summary': ''})
#   ('gubernatorial', {'url': '', 'summary': ''})
#   ('debt', {'url': '', 'summary': ''})
#   ('overall debt', {'url': '', 'summary': ''})
#   ('debt of the United States', {'url': '', 'summary': ''})
#   ('phone records', {'url': '', 'summary': ''})
#   ('privacy', {'url': '', 'summary': ''})
#   ('USAFreedom Act', {'url': '', 'summary': ''})
#   ('Ed Gillespie', {'url': '', 'summary': ''})
#   ('personhood amendment', {'url': '', 'summary': ''})
#   ('Export-Import Bank', {'url': '', 'summary': ''})
#   ('Bank', {'url': '', 'summary': ''})
#   ('health care bill', {'url': '', 'summary': ''})
#   ('House', {'url': '', 'summary': ''})
#   ('public option', {'url': '', 'summary': ''})
#   ('House health care bill', {'url': '', 'summary': ''})
#   ('health care coverage', {'url': '', 'summary': ''})
#   ('mandating', {'url': '', 'summary': ''})
#   ('mandate', {'url': '', 'summary': ''})
#   ('drug dealer', {'url': '', 'summary': ''})
#   ('overdosed', {'url': '', 'summary': ''})
#   ('overdose', {'url': '', 'summary': ''})
#   ('drug dealers', {'url': '', 'summary': ''})
#   ('GM', {'url': '', 'summary': ''})
#   ('coal industry', {'url': '', 'summary': ''})
#   ('industry', {'url': '', 'summary': ''})
#   ('coal', {'url': '', 'summary': ''})
#   ('No boots on the ground in Syria', {'url': '', 'summary': ''})
#   ('same-sex', {'url': '', 'summary': ''})
#   ('Abortion', {'url': '', 'summary': ''})
#   ('surgical procedure', {'url': '', 'summary': ''})
#   ('Alex Sinks', {'url': '', 'summary': ''})
#   ('Crime is rising', {'url': '', 'summary': ''})
#   ('rising', {'url': '', 'summary': ''})
#   ('Crime', {'url': '', 'summary': ''})
#   ('Chris Christie', {'url': '', 'summary': ''})
#   ('Democratic', {'url': '', 'summary': ''})
#   ('New Jersey Democratic', {'url': '', 'summary': ''})
#   ('New Jerseys Democratic legislature', {'url': '', 'summary': ''})
#   ('Colorado', {'url': '', 'summary': ''})
#   ('Colorado law', {'url': '', 'summary': ''})
#   ('ballot', {'url': '', 'summary': ''})
#   ('collectors', {'url': '', 'summary': ''})
#   ('World War II', {'url': '', 'summary': ''})
#   ('Our national debt', {'url': '', 'summary': ''})
#   ('national debt', {'url': '', 'summary': ''})
#   ('Kathryn Starkey', {'url': '', 'summary': ''})
#   ('liberal', {'url': '', 'summary': ''})
#   ('John McCain', {'url': '', 'summary': ''})
#   ('filibusters', {'url': '', 'summary': ''})
#   ('changing the rules for filibusters', {'url': '', 'summary': ''})
#   ('changing the rules for filibusters on presidential nominees', {'url': '', 'summary': ''})
#   ('crossing our borders', {'url': '', 'summary': ''})
#   ('Mexico', {'url': '', 'summary': ''})
#   ('crossing our borders illegally', {'url': '', 'summary': ''})
#   ('spay and neuter', {'url': '', 'summary': ''})
#   ('dog', {'url': '', 'summary': ''})
#   ('dog and cat', {'url': '', 'summary': ''})
#   ('apologize for America', {'url': '', 'summary': ''})
#   ('True', {'url': '', 'summary': ''})
#   ('PolitiFact', {'url': '', 'summary': ''})
#   ('Paul Krugman', {'url': '', 'summary': ''})
#   ('government worker', {'url': '', 'summary': ''})
#   ('taxpayers', {'url': '', 'summary': ''})
#   ('Georgia Log Cabin Republicans', {'url': '', 'summary': ''})
#   ('Log Cabin Republicans', {'url': '', 'summary': ''})
#   ('Georgia', {'url': '', 'summary': ''})
#   ('US citizens', {'url': '', 'summary': ''})
#   ('health care services', {'url': '', 'summary': ''})
#   ('2013 immigration bill', {'url': '', 'summary': ''})
#   ('elective', {'url': '', 'summary': ''})
#   ('abortions', {'url': '', 'summary': ''})
#   ('elective abortions', {'url': '', 'summary': ''})
#   ('elective abortion', {'url': '', 'summary': ''})
#   ('subsidize coverage', {'url': '', 'summary': ''})
#   ('Affordable Health Care Act', {'url': '', 'summary': ''})
#   ('Bill Pascrell', {'url': '', 'summary': ''})
#   ('Joe Straus', {'url': '', 'summary': ''})
#   ('sex education', {'url': '', 'summary': ''})
#   ('Tom Perriello', {'url': '', 'summary': ''})
#   ('voted to give tax breaks to foreign companies creating jobs in China', {'url': '', 'summary': ''})
#   ('bankrupting the state of Massachusetts', {'url': '', 'summary': ''})
#   ('public health insurance', {'url': '', 'summary': ''})
#   ('health care', {'url': '', 'summary': ''})
#   ('public health insurance plan', {'url': '', 'summary': ''})
#   ('plan to reform health care', {'url': '', 'summary': ''})
#   ("president's", {'url': '', 'summary': ''})
#   ('state lawmakers', {'url': '', 'summary': ''})
#   ('Wisconsin state lawmakers', {'url': '', 'summary': ''})
#   ('unemployment rate', {'url': '', 'summary': ''})
#   ('2 percentage points', {'url': '', 'summary': ''})
#   ('collapse of major investment banks', {'url': '', 'summary': ''})
#   ('2007', {'url': '', 'summary': ''})
#   ('collapse of major investment banks on Wall Street in 2007', {'url': '', 'summary': ''})
#   ('catastrophic, cascading collapse of major investment banks', {'url': '', 'summary': ''})
#   ('Wall Street', {'url': '', 'summary': ''})
#   ('Obama Administration', {'url': '', 'summary': ''})
#   ('Congressional Districts', {'url': '', 'summary': ''})
#   ('9-0 decision last week', {'url': '', 'summary': ''})
#   ('exceeded his constitutional authority', {'url': '', 'summary': ''})
#   ('the president', {'url': '', 'summary': ''})
#   ('constitutional authority', {'url': '', 'summary': ''})
#   ('Bill Clinton', {'url': '', 'summary': ''})
#   ('religious leaders', {'url': '', 'summary': ''})
#   ('founded by', {'url': '', 'summary': ''})
#   ('founded', {'url': '', 'summary': ''})
#   ('man-made global warming', {'url': '', 'summary': ''})
#   ('climate to change', {'url': '', 'summary': ''})
#   ('reserve', {'url': '', 'summary': ''})
#   ('Alaska', {'url': '', 'summary': ''})
#   ('one reserve', {'url': '', 'summary': ''})
#   ('trade deficit with America', {'url': '', 'summary': ''})
#   ('trade deficit', {'url': '', 'summary': ''})
#   ('Obamas', {'url': '', 'summary': ''})
#   ('Pres.', {'url': '', 'summary': ''})
#   ('financial institution', {'url': '', 'summary': ''})
#   ('transactions', {'url': '', 'summary': ''})
#   ('teen age', {'url': '', 'summary': ''})
#   ('young person', {'url': '', 'summary': ''})
#   ('Climatic Research Unit e-mails', {'url': '', 'summary': ''})
#   ('climate change', {'url': '', 'summary': ''})
#   ('science behind climate change has been pretty well debunked', {'url': '', 'summary': ''})
#   ('science behind climate change', {'url': '', 'summary': ''})
#   ('President Obamas lawsuit', {'url': '', 'summary': ''})
#   ('unconstitutional', {'url': '', 'summary': ''})
#   ('meat', {'url': '', 'summary': ''})
#   ('protein', {'url': '', 'summary': ''})
#   ('meat-based protein', {'url': '', 'summary': ''})
#   ('Cairo', {'url': '', 'summary': ''})
#   ('Egypt', {'url': '', 'summary': ''})
#   ('presidents first major foreign policy speech', {'url': '', 'summary': ''})
#   ('first major foreign policy speech in Cairo', {'url': '', 'summary': ''})
#   ('apologize for our country', {'url': '', 'summary': ''})
#   ('businesses', {'url': '', 'summary': ''})
#   ('Small Business Administration', {'url': '', 'summary': ''})
#   ('Small Business Development Center', {'url': '', 'summary': ''})
#   ('small businesses', {'url': '', 'summary': ''})
#   ('Nevada ranks 50th in the money received from the stimulus bill', {'url': '', 'summary': ''})
#   ('50th in the money received from the stimulus bill', {'url': '', 'summary': ''})
#   ('Demond Means', {'url': '', 'summary': ''})
#   ('Milwaukee Public Schools', {'url': '', 'summary': ''})
#   ('turnaround district', {'url': '', 'summary': ''})
#   ('waterboarding', {'url': '', 'summary': ''})
#   ('enhanced interrogation methods', {'url': '', 'summary': ''})
#   ('enhanced interrogation', {'url': '', 'summary': ''})
#   ('seniors', {'url': '', 'summary': ''})
#   ('destroying Medicare', {'url': '', 'summary': ''})
#   ('proposing destroying Medicare for seniors', {'url': '', 'summary': ''})
#   ('lawmakers', {'url': '', 'summary': ''})
#   ('Legislature', {'url': '', 'summary': ''})
#   ('think terrorists just need a good talking to', {'url': '', 'summary': ''})
#   ('senior citizens', {'url': '', 'summary': ''})
#   ('violent crime', {'url': '', 'summary': ''})
#   ('arrested', {'url': '', 'summary': ''})
#   ('violent crimes', {'url': '', 'summary': ''})
#   ('cabinet', {'url': '', 'summary': ''})
#   ('his cabinet', {'url': '', 'summary': ''})
#   ('Maine', {'url': '', 'summary': ''})
#   ('Jim Doyle', {'url': '', 'summary': ''})
#   ('Mary Burke', {'url': '', 'summary': ''})
#   ('commerce secretary', {'url': '', 'summary': ''})
#   ('1990s ethics violations charges', {'url': '', 'summary': ''})
#   ('1990', {'url': '', 'summary': ''})
#   ('abortion clinics', {'url': '', 'summary': ''})
#   ('proposed immigration bill', {'url': '', 'summary': ''})
#   ('A proposed immigration bill', {'url': '', 'summary': ''})
#   ('immigration bill', {'url': '', 'summary': ''})
#   ('sales tax', {'url': '', 'summary': ''})
#   ('state sales tax', {'url': '', 'summary': ''})
#   ('5', {'url': '', 'summary': ''})
#   ('gun registry', {'url': '', 'summary': ''})
#   ('gun confiscation', {'url': '', 'summary': ''})
#   ('Free Flow of Information Act of 2009', {'url': '', 'summary': ''})
#   ('Free Flow of Information Act', {'url': '', 'summary': ''})
#   ('Sandy', {'url': '', 'summary': ''})
#   ('Hurricane', {'url': '', 'summary': ''})
#   ('Hurricane Sandy', {'url': '', 'summary': ''})
#   ('disaster relief', {'url': '', 'summary': ''})
#   ('Iran nuclear deal', {'url': '', 'summary': ''})
#   ('150 billion', {'url': '', 'summary': ''})
#   ('military nuclear capability', {'url': '', 'summary': ''})
#   ('flag', {'url': '', 'summary': ''})
#   ('American', {'url': '', 'summary': ''})
#   ('American flag', {'url': '', 'summary': ''})
#   ('Dodd-Frank', {'url': '', 'summary': ''})
#   ('Community bank', {'url': '', 'summary': ''})
#   ('last spring', {'url': '', 'summary': ''})
#   ('Will Rasmussen', {'url': '', 'summary': ''})
#   ('Rasmussen Reports', {'url': '', 'summary': ''})
#   ('voted no', {'url': '', 'summary': ''})
#   ('no', {'url': '', 'summary': ''})
#   ('thousands of illegal voters', {'url': '', 'summary': ''})
#   ('commonwealth', {'url': '', 'summary': ''})
#   ('illegal voters', {'url': '', 'summary': ''})
#   ('Corrine Brown', {'url': '', 'summary': ''})
#   ('Socialists', {'url': '', 'summary': ''})
#   ('Alcee Hastings', {'url': '', 'summary': ''})
#   ('Frederica Wilson', {'url': '', 'summary': ''})
#   ('Chris Coons', {'url': '', 'summary': ''})
#   ('Marxist', {'url': '', 'summary': ''})
#   ('Marxist beliefs', {'url': '', 'summary': ''})
#   ('Ice Bucket Challenge', {'url': '', 'summary': ''})
#   ('ALS', {'url': '', 'summary': ''})
#   ('ALS Ice Bucket Challenge', {'url': '', 'summary': ''})
#   ('fundraising', {'url': '', 'summary': ''})
#   ('big government', {'url': '', 'summary': ''})
#   ('Diane Black', {'url': '', 'summary': ''})
#   ('fund', {'url': '', 'summary': ''})
#   ('voted to fund Obamacare', {'url': '', 'summary': ''})
#   ('breast pump', {'url': '', 'summary': ''})
#   ('babies', {'url': '', 'summary': ''})
#   ('Mayor', {'url': '', 'summary': ''})
#   ('Fung', {'url': '', 'summary': ''})
#   ('public schools', {'url': '', 'summary': ''})
#   ('Mayor Fung', {'url': '', 'summary': ''})
#   ('private charter school', {'url': '', 'summary': ''})
#   ('Central Falls', {'url': '', 'summary': ''})
#   ('municipalities', {'url': '', 'summary': ''})
#   ('police officers', {'url': '', 'summary': ''})
#   ('retirees', {'url': '', 'summary': ''})
#   ('plant', {'url': '', 'summary': ''})
#   ('ecosystem', {'url': '', 'summary': ''})
#   ('animal', {'url': '', 'summary': ''})
#   ('Fast and Furious', {'url': '', 'summary': ''})
#   ('Bush administration', {'url': '', 'summary': ''})
#   ('Fast and Furious gun-walking program', {'url': '', 'summary': ''})
#   ('like it', {'url': '', 'summary': ''})
#   ('Donald Trumps', {'url': '', 'summary': ''})
#   ('Donald Trump', {'url': '', 'summary': ''})
#   ('Proposition 1', {'url': '', 'summary': ''})
#   ('Austin', {'url': '', 'summary': ''})
#   ('City', {'url': '', 'summary': ''})
#   ('City-run', {'url': '', 'summary': ''})
#   ('Eddie Bernice Johnson', {'url': '', 'summary': ''})
#   ('Take a Look at the background', {'url': '', 'summary': ''})
#   ('Alicia Machado', {'url': '', 'summary': ''})
#   ('Take a Look at the background of Alicia Machado', {'url': '', 'summary': ''})
#   ('sex tape', {'url': '', 'summary': ''})
#   ('Nazi party', {'url': '', 'summary': ''})
#   ('internment of Muslims', {'url': '', 'summary': ''})
#   ('9-9-9', {'url': '', 'summary': ''})
#   ('9-9-9 plan', {'url': '', 'summary': ''})
#   ('Obamas Kenyan birth certificate', {'url': '', 'summary': ''})
#   ('Birthers', {'url': '', 'summary': ''})
#   ('Kenyan birth certificate', {'url': '', 'summary': ''})
#   ('Kenyan', {'url': '', 'summary': ''})
#   ('Texas State Board of Education', {'url': '', 'summary': ''})
#   ('textbooks', {'url': '', 'summary': ''})
#   ('State Board of Education', {'url': '', 'summary': ''})
#   ('Biden Crime Bill', {'url': '', 'summary': ''})
#   ('murder', {'url': '', 'summary': ''})
#   ('Israeli ambassador', {'url': '', 'summary': ''})
#   ('Israel ambassador', {'url': '', 'summary': ''})
#   ('Iraq', {'url': '', 'summary': ''})
#   ('wars', {'url': '', 'summary': ''})
#   ('HB 97', {'url': '', 'summary': ''})
#   ('taxpayer dollars', {'url': '', 'summary': ''})
#   ('This years redistricting', {'url': '', 'summary': ''})
#   ('redistricting process in Tennessee', {'url': '', 'summary': ''})
#   ('Miami Dolphins', {'url': '', 'summary': ''})
#   ('deficit spending', {'url': '', 'summary': ''})
#   ('states are floundering', {'url': '', 'summary': ''})
#   ('City Hall', {'url': '', 'summary': ''})
#   ('White House budget plans', {'url': '', 'summary': ''})
#   ('April 11', {'url': '', 'summary': ''})
#   ('budget plans', {'url': '', 'summary': ''})
#   ('Iranians', {'url': '', 'summary': ''})
#   ('doubled the deficit', {'url': '', 'summary': ''})
#   ('FreshFromFlorida', {'url': '', 'summary': ''})
#   ('Florida Department of Agricultures', {'url': '', 'summary': ''})
#   ('women', {'url': '', 'summary': ''})
#   ('men', {'url': '', 'summary': ''})
#   ("Women's March on Washington", {'url': '', 'summary': ''})
#   ('Marquette University', {'url': '', 'summary': ''})
#   ('Gov. Scott Walker', {'url': '', 'summary': ''})
#   ('raise your taxes to 90 percent', {'url': '', 'summary': ''})
#   ('Small businesses', {'url': '', 'summary': ''})
#   ('business', {'url': '', 'summary': ''})
#   ('Small business', {'url': '', 'summary': ''})
#   ('gross sales', {'url': '', 'summary': ''})
#   ('Marcy Kaptur', {'url': '', 'summary': ''})
#   ('Air Force', {'url': '', 'summary': ''})
#   ('military service', {'url': '', 'summary': ''})
#   ('health care plan', {'url': '', 'summary': ''})
#   ("John McCain's", {'url': '', 'summary': ''})
#   ('FCAT', {'url': '', 'summary': ''})
#   ('test', {'url': '', 'summary': ''})
#   ('1 percent', {'url': '', 'summary': ''})
#   ('FCAT test', {'url': '', 'summary': ''})
#   ('privatize', {'url': '', 'summary': ''})
#   ('privatize Social Security', {'url': '', 'summary': ''})
#   ('Sean Duffy', {'url': '', 'summary': ''})
#   ('president', {'url': '', 'summary': ''})
#   ('Texas-Mexico border', {'url': '', 'summary': ''})
#   ('House Speaker', {'url': '', 'summary': ''})
#   ('Nancy Pelosi', {'url': '', 'summary': ''})
#   ('Newt Gingrich', {'url': '', 'summary': ''})
#   ('John DePetro', {'url': '', 'summary': ''})
#   ('sexually assaulting a female co-worker', {'url': '', 'summary': ''})
#   ('accused of sexually assaulting a female co-worker', {'url': '', 'summary': ''})
#   ('Perry flat tax plan', {'url': '', 'summary': ''})
#   ('George Allens flat tax plan', {'url': '', 'summary': ''})
#   ('small business owners', {'url': '', 'summary': ''})
#   ('Anita Dunn', {'url': '', 'summary': ''})
#   ('White House communications director', {'url': '', 'summary': ''})
#   ('Mao Tse-tung', {'url': '', 'summary': ''})
#   ('stimulus', {'url': '', 'summary': ''})
#   ('tax dollars', {'url': '', 'summary': ''})
#   ('a trillion of our tax dollars', {'url': '', 'summary': ''})
#   ('Martin Heinrich', {'url': '', 'summary': ''})
#   ('economy', {'url': '', 'summary': ''})
#   ('Businesses', {'url': '', 'summary': ''})
#   ('raising their prices', {'url': '', 'summary': ''})
#   ('franchised dealer', {'url': '', 'summary': ''})
#   ('direct sales', {'url': '', 'summary': ''})
#   ('franchised dealer model', {'url': '', 'summary': ''})
#   ('Pro-Stimulus', {'url': '', 'summary': ''})
#   ('economist', {'url': '', 'summary': ''})
#   ('Stimulus', {'url': '', 'summary': ''})
#   ('Russ Feingold', {'url': '', 'summary': ''})
#   ('Social Security benefits to illegal immigrants', {'url': '', 'summary': ''})
#   ('stand your ground law', {'url': '', 'summary': ''})
#   ('Floridas', {'url': '', 'summary': ''})
#   ('Homicides against blacks', {'url': '', 'summary': ''})
#   ('executive order', {'url': '', 'summary': ''})
#   ('newly legalized', {'url': '', 'summary': ''})
#   ('Department of Community Affairs', {'url': '', 'summary': ''})
#   ('medical', {'url': '', 'summary': ''})
#   ('dental', {'url': '', 'summary': ''})
#   ('binding arbitration', {'url': '', 'summary': ''})
#   ('wage settlement', {'url': '', 'summary': ''})
#   ('arbitration', {'url': '', 'summary': ''})
#   ('Chet said no', {'url': '', 'summary': ''})
#   ('take away our guns', {'url': '', 'summary': ''})
#   ('Warren Buffett', {'url': '', 'summary': ''})
#   ('Jeff Greenes', {'url': '', 'summary': ''})
#   ('ordinance', {'url': '', 'summary': ''})
#   ('San Antonio', {'url': '', 'summary': ''})
#   ('proposed San Antonio ordinance', {'url': '', 'summary': ''})
#   ('womens restrooms', {'url': '', 'summary': ''})
#   ('7,000 Americans lost their lives to climate change-fueled events last year', {'url': '', 'summary': ''})
# ...
#   {'head': '911', 'type': 'applies to jurisdiction', 'tail': 'Texans', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'DREAM Act', 'type': 'instance of', 'tail': 'amnesty', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'DREAM Act', 'type': 'main subject', 'tail': 'amnesty', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'DREAM Act', 'type': 'main subject', 'tail': 'amnesty to over two million illegal aliens', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'doubled the size of government since he took office', 'type': 'creator', 'tail': 'Barack Obama', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Trans-Pacific Partnership', 'type': 'participant', 'tail': 'China', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'China', 'type': 'member of', 'tail': 'Trans-Pacific Partnership', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'China', 'type': 'participant in', 'tail': 'Trans-Pacific Partnership', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Georgia', 'type': 'legislative body', 'tail': 'Georgia Legislatures', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Georgia Legislatures', 'type': 'applies to jurisdiction', 'tail': 'Georgia', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Georgia', 'type': 'legislative body', 'tail': 'Legislature', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Legislature', 'type': 'applies to jurisdiction', 'tail': 'Georgia', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Trade Promotion Authority', 'type': 'instance of', 'tail': 'fast-track', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Trade Promotion Authority', 'type': 'instance of', 'tail': 'Fast-track', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Guatemala', 'type': 'shares border with', 'tail': 'Mexico', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Mexico', 'type': 'shares border with', 'tail': 'Guatemala', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'nursing home', 'type': 'subclass of', 'tail': 'seniors', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Medicaid', 'type': 'located in the administrative territorial entity', 'tail': 'Virginias', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'nursing homes', 'type': 'subclass of', 'tail': 'seniors', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Chinas', 'type': 'product or material produced', 'tail': 'steel', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Rob Portmans', 'type': 'country of citizenship', 'tail': 'Chinas', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Rob Portmans', 'type': 'employer', 'tail': 'Chinas', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Clinton', 'type': 'spouse', 'tail': 'Obama', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Cleveland police', 'type': 'instance of', 'tail': 'officers', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'police', 'type': 'applies to jurisdiction', 'tail': 'Cleveland', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Cleveland police', 'type': 'subclass of', 'tail': 'officers', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Mike Martinez', 'type': 'position held', 'tail': 'Austin mayoral candidate', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Mike Martinez', 'type': 'candidacy in election', 'tail': 'Austin mayoral candidate', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Austin mayoral candidate', 'type': 'candidate', 'tail': 'Mike Martinez', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'plan', 'type': 'named after', 'tail': 'Barack Obama', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Barack Obama', 'type': 'field of work', 'tail': 'small businesses', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': "Barack Obama's plan", 'type': 'named after', 'tail': 'Obama', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'United States of America', 'type': 'diplomatic relation', 'tail': 'Russia', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Russia', 'type': 'diplomatic relation', 'tail': 'United States of America', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Ukraine', 'type': 'diplomatic relation', 'tail': 'United States of America', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'United States of America', 'type': 'diplomatic relation', 'tail': 'Ukraine', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Ukraine', 'type': 'shares border with', 'tail': 'Russia', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Russia', 'type': 'shares border with', 'tail': 'Ukraine', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'budget agreement', 'type': 'facet of', 'tail': 'fiscally responsible', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'state spending', 'type': 'part of', 'tail': 'budget agreement', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'state spending', 'type': 'subclass of', 'tail': 'budget', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'regressive', 'type': 'subclass of', 'tail': 'tax reform', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': '9-9-9 tax reform plan', 'type': 'opposite of', 'tail': 'regressive', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': '9-9-9 tax reform', 'type': 'opposite of', 'tail': 'regressive', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Obamas time', 'type': 'country', 'tail': 'U.S.', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Anglos', 'type': 'opposite of', 'tail': 'African Americans', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'African Americans', 'type': 'opposite of', 'tail': 'Anglos', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'gentrified', 'type': 'has effect', 'tail': '18th congressional district', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'bridge', 'type': 'located in the administrative territorial entity', 'tail': 'Alaska', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'a bridge', 'type': 'located in the administrative territorial entity', 'tail': 'Alaska', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Alaska', 'type': 'population', 'tail': '50', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Barack Obama', 'type': 'mother', 'tail': 'his mother', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'his mother', 'type': 'child', 'tail': 'Barack Obama', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Tom Daschle', 'type': 'position held', 'tail': 'Sen.', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Tom Daschle', 'type': 'member of', 'tail': 'Sen.', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Tom Daschle', 'type': 'member of political party', 'tail': 'Sen.', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Common Core', 'type': 'developer', 'tail': 'Department of Education', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Department of Education', 'type': 'instance of', 'tail': 'national school board', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Common Core', 'type': 'used by', 'tail': 'school board', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Leander', 'type': 'shares border with', 'tail': 'Austin', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Austin', 'type': 'shares border with', 'tail': 'Leander', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Leander', 'type': 'twinned administrative body', 'tail': 'Austin', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Austin', 'type': 'twinned administrative body', 'tail': 'Leander', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Leander-to-Austin train', 'type': 'located in the administrative territorial entity', 'tail': 'Austin', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'ISIS', 'type': 'founded by', 'tail': 'Barack Obama', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Hillary Clinton', 'type': 'influenced by', 'tail': 'Barack Obama', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Barack Obamas', 'type': 'position held', 'tail': 'policies', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'border', 'type': 'creator', 'tail': 'Barack Obamas', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Barack Obamas', 'type': 'occupation', 'tail': 'policies', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Eric Holder', 'type': 'member of', 'tail': 'New Black Panther Party', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'his campaign', 'type': 'named after', 'tail': 'Mr. Trump', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'his campaign', 'type': 'instance of', 'tail': 'self-financing', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Donald Trump', 'type': 'candidacy in election', 'tail': '2016', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'George Tenet', 'type': 'position held', 'tail': 'President of the United States', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Colorado caucus system', 'type': 'instance of', 'tail': 'rigged', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Colorado caucus', 'type': 'instance of', 'tail': 'rigged', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Colorado caucus system for selecting Republican delegates', 'type': 'instance of', 'tail': 'rigged', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Bob Buckhorn', 'type': 'position held', 'tail': 'Tampa mayoral', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Bob Buckhorn', 'type': 'position held', 'tail': 'mayoral', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Tampa mayoral', 'type': 'candidate', 'tail': 'Bob Buckhorn', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Bob Buckhorn', 'type': 'candidacy in election', 'tail': 'Tampa mayoral', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': '911 hijackers', 'type': 'country', 'tail': 'Saudi Arabia', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'hijackers', 'type': 'point in time', 'tail': '911', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': '911 hijackers', 'type': 'country of origin', 'tail': 'Saudi Arabia', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Rex Ryan', 'type': 'member of sports team', 'tail': 'New York', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Rex Ryan', 'type': 'sport', 'tail': 'football', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Rex Ryan', 'type': 'employer', 'tail': 'New York', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'automobile', 'type': 'discoverer or inventor', 'tail': 'Americans', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'automobile', 'type': 'country of origin', 'tail': 'Americans', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'automobile', 'type': 'designed by', 'tail': 'Americans', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'universal health care', 'type': 'subclass of', 'tail': 'health care', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'health care', 'type': 'facet of', 'tail': 'universal health care', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'health care', 'type': 'legislated by', 'tail': 'Congress', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Barack Obama', 'type': 'position held', 'tail': 'U.S. Senate', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Alan Grayson', 'type': 'employer', 'tail': 'House of Representatives', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Alan Grayson', 'type': 'position held', 'tail': '435 members of the U.S. House of Representatives', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Alan Grayson campaign', 'type': 'number of participants', 'tail': '435 members of the U.S. House of Representatives', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'in 2012', 'type': 'point in time', 'tail': '2012', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': '2012.', 'type': 'point in time', 'tail': '2012', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Barack Obamas desk', 'type': 'position held', 'tail': 'President', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Chesterfield', 'type': 'head of government', 'tail': 'Dan Gecker', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Dan Gecker', 'type': 'place of birth', 'tail': 'Chesterfield', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Dan Gecker', 'type': 'place of birth', 'tail': 'Chesterfield county', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'lawbanninglethalrat trapping', 'type': 'applies to jurisdiction', 'tail': 'D.C.', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'City Council', 'type': 'applies to jurisdiction', 'tail': 'D.C.', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'D.C.', 'type': 'legislative body', 'tail': 'City Council', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'sparklers', 'type': 'subclass of', 'tail': 'fireworks', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'sparkler', 'type': 'subclass of', 'tail': 'fireworks', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'comprehensive sex education', 'type': 'subclass of', 'tail': 'education', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'comprehensive sex education', 'type': 'instance of', 'tail': 'education', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Donna Campbell', 'type': 'field of work', 'tail': 'medicine', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'health care', 'type': 'facet of', 'tail': 'Medicare', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Donna Campbell', 'type': 'field of work', 'tail': 'health care', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Tim Kaine', 'type': 'position held', 'tail': 'raise taxes on everyone', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Tim Kaine', 'type': 'position held', 'tail': 'wants to raise taxes on everyone', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Tim Kaine', 'type': 'member of political party', 'tail': 'wants to raise taxes on everyone', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'anti-business litigation climate', 'type': 'applies to jurisdiction', 'tail': 'Wisconsin', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'anti-business litigation climate', 'type': 'located in the administrative territorial entity', 'tail': 'Wisconsin', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'toothbrush', 'type': 'has part', 'tail': 'toothpaste', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'toothpaste', 'type': 'different from', 'tail': 'toothbrush', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'toothbrush', 'type': 'different from', 'tail': 'toothpaste', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Providence', 'type': 'capital of', 'tail': 'R.I.', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'R.I.', 'type': 'capital', 'tail': 'Providence', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Scott Walkers income tax plan', 'type': 'instance of', 'tail': 'tax hike', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'income tax', 'type': 'subclass of', 'tail': 'tax', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'income tax', 'type': 'subclass of', 'tail': 'tax hike', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Mahoning Valley', 'type': 'country', 'tail': 'China', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'China', 'type': 'contains administrative territorial entity', 'tail': 'Mahoning Valley', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'sucked the jobs out', 'type': 'country', 'tail': 'China', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'pork barrel project', 'type': 'subclass of', 'tail': 'earmark', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'United States', 'type': 'legislative body', 'tail': 'Congress', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Congress', 'type': 'country', 'tail': 'United States', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'November', 'type': 'participant', 'tail': 'Democrats', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'November', 'type': 'candidate', 'tail': 'Democrats', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Democrats top target this November', 'type': 'point in time', 'tail': 'November', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Milwaukee County', 'type': 'capital', 'tail': 'Milwaukee', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'boots', 'type': 'located in the administrative territorial entity', 'tail': 'Wisconsin', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'boots', 'type': 'country of origin', 'tail': 'Wisconsin', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'boots', 'type': 'named after', 'tail': 'Wisconsin', 'meta': {'': {'spans': [[0, 64]]}}}
# Sources:
#   ('', {'article_title': None, 'article_publish_date': None})
# (6514, None)

# %%
filename = f"LIAR_fake_entites_intermediate_RAW_{articles_limit}.html"
save_kb(kb, os.path.basename(filename)[:-5]  + ".p")

# %% [markdown]
# ##### FOR REAL DATA (INTERMEDIATE)

# %%
texts = []
_data = data_filepath["real"]
articles_limit = 4505
# articles_limit = int(input(f"enter number of docs to take (max : {len(_data)}): "))
print(f"taking {articles_limit} docs in KG")

countt = 0
for d_text in _data:
    _txt = " ".join(clean_document(d_text))
    # if len(_txt.split()) > 2000:
    #     continue
    texts.append(_txt)
    countt += 1
    if countt > articles_limit:
        break
# Out:
# taking 4505 docs in KG

# %%
len(texts)
# Out:
# 4503

# %%
kb = KB()
max_lenn = 1000
for text in tqdm(texts):
    # print(len(text.split()))
    # print(text)
    kb = from_text_to_kb(text, "", kb = kb,
                         useGPU = 1, 
                         verbose = 0, 
                         span_length = spann, 
                         max_doc_text = max_lenn,
                         useWiki = 0,                       # KEEPING IT 0, AS FOR NOW WE ONLY NEED THE POSSIBLE ENTITIES
                         offlineWiki = offline_wikipedia)
# Out:
# 100%|██████████| 4503/4503 [22:46<00:00,  3.29it/s]

# %%
len(kb.entities), kb.print()
# Out:
# Entities:
#   ('New Jersey', {'url': '', 'summary': ''})
#   ('New York', {'url': '', 'summary': ''})
#   ('high-tax states', {'url': '', 'summary': ''})
#   ('South', {'url': '', 'summary': ''})
#   ('government', {'url': '', 'summary': ''})
#   ('recession', {'url': '', 'summary': ''})
#   ('its attempt to blunt the recession', {'url': '', 'summary': ''})
#   ('personal income tax', {'url': '', 'summary': ''})
#   ('U.S.', {'url': '', 'summary': ''})
#   ('income tax', {'url': '', 'summary': ''})
#   ('tax breaks', {'url': '', 'summary': ''})
#   ('John Loughlin', {'url': '', 'summary': ''})
#   ('voted to let people accused of domestic violence keep their guns', {'url': '', 'summary': ''})
#   ('On torture', {'url': '', 'summary': ''})
#   ('torture', {'url': '', 'summary': ''})
#   ('Taylor Swift', {'url': '', 'summary': ''})
#   ('national debt', {'url': '', 'summary': ''})
#   ('interest', {'url': '', 'summary': ''})
#   ('fast food worker', {'url': '', 'summary': ''})
#   ('public assistance', {'url': '', 'summary': ''})
#   ('fast food', {'url': '', 'summary': ''})
#   ('JoAnne Kloppenburg', {'url': '', 'summary': ''})
#   ('More equal society', {'url': '', 'summary': ''})
#   ('more equal society', {'url': '', 'summary': ''})
#   ("Iran's nuclear ambitions are advancing", {'url': '', 'summary': ''})
#   ('Iran', {'url': '', 'summary': ''})
#   ('nuclear ambitions are advancing', {'url': '', 'summary': ''})
#   ("Iran's nuclear arsenal", {'url': '', 'summary': ''})
#   ('Mitch McConnell', {'url': '', 'summary': ''})
#   ('Republicans', {'url': '', 'summary': ''})
#   ('took control of the Senate', {'url': '', 'summary': ''})
#   ('Arlen Specters', {'url': '', 'summary': ''})
#   ('Arlen Specter', {'url': '', 'summary': ''})
#   ('Democrats', {'url': '', 'summary': ''})
#   ('1908 Model T', {'url': '', 'summary': ''})
#   ('1908', {'url': '', 'summary': ''})
#   ('Model T', {'url': '', 'summary': ''})
#   ('Florida', {'url': '', 'summary': ''})
#   ('state', {'url': '', 'summary': ''})
#   ('nation', {'url': '', 'summary': ''})
#   ('Gov.', {'url': '', 'summary': ''})
#   ('Scott Walker', {'url': '', 'summary': ''})
#   ('John McCain', {'url': '', 'summary': ''})
#   ('last year', {'url': '', 'summary': ''})
#   ('George Bush', {'url': '', 'summary': ''})
#   ('education funding per pupil', {'url': '', 'summary': ''})
#   ('Texas', {'url': '', 'summary': ''})
#   ('44th nationally', {'url': '', 'summary': ''})
#   ('charter schools', {'url': '', 'summary': ''})
#   ('charter school', {'url': '', 'summary': ''})
#   ('McDonalds', {'url': '', 'summary': ''})
#   ('ColoradoCare', {'url': '', 'summary': ''})
#   ('Joe Straus', {'url': '', 'summary': ''})
#   ('Jewish', {'url': '', 'summary': ''})
#   ('Texas House', {'url': '', 'summary': ''})
#   ('speaker of the Texas House', {'url': '', 'summary': ''})
#   ('premiums have doubled and tripled in Wisconsin', {'url': '', 'summary': ''})
#   ('Obamacare', {'url': '', 'summary': ''})
#   ('Wisconsin', {'url': '', 'summary': ''})
#   ('gulag', {'url': '', 'summary': ''})
#   ('North Korea', {'url': '', 'summary': ''})
#   ('South Korea', {'url': '', 'summary': ''})
#   ('Seamus', {'url': '', 'summary': ''})
#   ('Mitt Romney', {'url': '', 'summary': ''})
#   ('Romney', {'url': '', 'summary': ''})
#   ('trans-gender', {'url': '', 'summary': ''})
#   ('non-discrimination', {'url': '', 'summary': ''})
#   ('discrimination', {'url': '', 'summary': ''})
#   ('took office', {'url': '', 'summary': ''})
#   ('eight years ago', {'url': '', 'summary': ''})
#   ('America', {'url': '', 'summary': ''})
#   ('Earth', {'url': '', 'summary': ''})
#   ('Superdelegates', {'url': '', 'summary': ''})
#   ('1984', {'url': '', 'summary': ''})
#   ('Superdelegate', {'url': '', 'summary': ''})
#   ('metro Atlanta', {'url': '', 'summary': ''})
#   ('union', {'url': '', 'summary': ''})
#   ('Atlanta', {'url': '', 'summary': ''})
#   ('Iraq', {'url': '', 'summary': ''})
#   ('bombings', {'url': '', 'summary': ''})
#   ('what was going on last year', {'url': '', 'summary': ''})
#   ('Republicans last controlled the presidency and Congress', {'url': '', 'summary': ''})
#   ('Republicans last controlled the presidency', {'url': '', 'summary': ''})
#   ('Congress', {'url': '', 'summary': ''})
#   ('United States', {'url': '', 'summary': ''})
#   ('Senate', {'url': '', 'summary': ''})
#   ('John F. Kennedy School of Government', {'url': '', 'summary': ''})
#   ('Harvard University', {'url': '', 'summary': ''})
#   ('John F. Kennedy', {'url': '', 'summary': ''})
#   ('President', {'url': '', 'summary': ''})
#   ('refugee', {'url': '', 'summary': ''})
#   ('more rigorous screening', {'url': '', 'summary': ''})
#   ('boyfriend', {'url': '', 'summary': ''})
#   ('girlfriend', {'url': '', 'summary': ''})
#   ('George W. Bush', {'url': '', 'summary': ''})
#   ('Governor', {'url': '', 'summary': ''})
#   ('Obama', {'url': '', 'summary': ''})
#   ('Barack Obama', {'url': '', 'summary': ''})
#   ('President Obama', {'url': '', 'summary': ''})
#   ('the interior of the country', {'url': '', 'summary': ''})
#   ('provisional ballot', {'url': '', 'summary': ''})
#   ('provisional ballot in Florida', {'url': '', 'summary': ''})
#   ('last presidential election', {'url': '', 'summary': ''})
#   ('presidential election', {'url': '', 'summary': ''})
#   ('new taxes', {'url': '', 'summary': ''})
#   ('politicians', {'url': '', 'summary': ''})
#   ('taxes', {'url': '', 'summary': ''})
#   ('military record', {'url': '', 'summary': ''})
#   ('Mark Kirks', {'url': '', 'summary': ''})
#   ('his military record', {'url': '', 'summary': ''})
#   ('official White House Twitter account', {'url': '', 'summary': ''})
#   ('Twitter', {'url': '', 'summary': ''})
#   ('John McCain Twitter account', {'url': '', 'summary': ''})
#   ('2010 election', {'url': '', 'summary': ''})
#   ('2010', {'url': '', 'summary': ''})
#   ('September 11, 2001', {'url': '', 'summary': ''})
#   ('assassinated', {'url': '', 'summary': ''})
#   ('Veterans Day', {'url': '', 'summary': ''})
#   ('Vietnam', {'url': '', 'summary': ''})
#   ('Annual precipitation', {'url': '', 'summary': ''})
#   ('Rhode Island', {'url': '', 'summary': ''})
#   ('precipitation', {'url': '', 'summary': ''})
#   ('Annual', {'url': '', 'summary': ''})
#   ('Atlantic Ocean', {'url': '', 'summary': ''})
#   ('appeals court', {'url': '', 'summary': ''})
#   ('Wisconsin appeals court', {'url': '', 'summary': ''})
#   ('minimum wage', {'url': '', 'summary': ''})
#   ('10', {'url': '', 'summary': ''})
#   ('10.10 an hour', {'url': '', 'summary': ''})
#   ('secretary', {'url': '', 'summary': ''})
#   ('Warren Buffett', {'url': '', 'summary': ''})
#   ('his secretary', {'url': '', 'summary': ''})
#   ('developed nations', {'url': '', 'summary': ''})
#   ('country', {'url': '', 'summary': ''})
#   ('New Orleans', {'url': '', 'summary': ''})
#   ('potato pest management', {'url': '', 'summary': ''})
#   ('Earmark', {'url': '', 'summary': ''})
#   ('federal spending bill', {'url': '', 'summary': ''})
#   ('Earmarks', {'url': '', 'summary': ''})
#   ('bike infrastructure', {'url': '', 'summary': ''})
#   ('freeway', {'url': '', 'summary': ''})
#   ('Department of Transportation', {'url': '', 'summary': ''})
#   ('stimulus', {'url': '', 'summary': ''})
#   ('fee', {'url': '', 'summary': ''})
#   ('tax', {'url': '', 'summary': ''})
#   ('Georgias tax and fee structure', {'url': '', 'summary': ''})
#   ('tax cut', {'url': '', 'summary': ''})
#   ('Hosni Mubaraks', {'url': '', 'summary': ''})
#   ('Egypt', {'url': '', 'summary': ''})
#   ('Israel', {'url': '', 'summary': ''})
#   ('Chicago Public Schools', {'url': '', 'summary': ''})
#   ('United States of America', {'url': '', 'summary': ''})
#   ('urban school system', {'url': '', 'summary': ''})
#   ('1999', {'url': '', 'summary': ''})
#   ('since 1999', {'url': '', 'summary': ''})
#   ('Amtrak', {'url': '', 'summary': ''})
#   ('Northeast Corridor', {'url': '', 'summary': ''})
#   ('Ohioans', {'url': '', 'summary': ''})
#   ('Ohio', {'url': '', 'summary': ''})
#   ('The Northeast Corridor', {'url': '', 'summary': ''})
#   ('Thomas DiMassimo', {'url': '', 'summary': ''})
#   ('Ohio rally', {'url': '', 'summary': ''})
#   ('teacher pay', {'url': '', 'summary': ''})
#   ('New Mexico', {'url': '', 'summary': ''})
#   ('29th', {'url': '', 'summary': ''})
#   ('John Kasich', {'url': '', 'summary': ''})
#   ('Republican', {'url': '', 'summary': ''})
#   ('Ohio Governor', {'url': '', 'summary': ''})
#   ('Governor of Ohio', {'url': '', 'summary': ''})
#   ('Cayman Islands', {'url': '', 'summary': ''})
#   ('tax haven', {'url': '', 'summary': ''})
#   ('Rick Scott', {'url': '', 'summary': ''})
#   ('governor', {'url': '', 'summary': ''})
#   ('Newt Gingrich', {'url': '', 'summary': ''})
#   ('Speaker', {'url': '', 'summary': ''})
#   ('Gingrich', {'url': '', 'summary': ''})
#   ('Gingrichs tax plan', {'url': '', 'summary': ''})
#   ('earmark', {'url': '', 'summary': ''})
#   ('Ted Strickland', {'url': '', 'summary': ''})
#   ('the NRA', {'url': '', 'summary': ''})
#   ('NRA', {'url': '', 'summary': ''})
#   ('this campaign', {'url': '', 'summary': ''})
#   ('2002 general election', {'url': '', 'summary': ''})
#   ('2002', {'url': '', 'summary': ''})
#   ('2012 general election', {'url': '', 'summary': ''})
#   ('2012', {'url': '', 'summary': ''})
#   ('Kolkata', {'url': '', 'summary': ''})
#   ('India', {'url': '', 'summary': ''})
#   ('Russia', {'url': '', 'summary': ''})
#   ('China', {'url': '', 'summary': ''})
#   ('Mexico', {'url': '', 'summary': ''})
#   ('attempted rape', {'url': '', 'summary': ''})
#   ('rape', {'url': '', 'summary': ''})
#   ('climate change denier', {'url': '', 'summary': ''})
#   ('climate change', {'url': '', 'summary': ''})
#   ('denial', {'url': '', 'summary': ''})
#   ('Miami-Dade', {'url': '', 'summary': ''})
#   ('Broward', {'url': '', 'summary': ''})
#   ('Broward counties', {'url': '', 'summary': ''})
#   ('partial-birth abortion', {'url': '', 'summary': ''})
#   ('barbaric procedure', {'url': '', 'summary': ''})
#   ('direct payment', {'url': '', 'summary': ''})
#   ('farm subsidy', {'url': '', 'summary': ''})
#   ('farm subsidy program', {'url': '', 'summary': ''})
#   ('nuclear deal with Iran', {'url': '', 'summary': ''})
#   ('nuclear deal', {'url': '', 'summary': ''})
#   ('major country', {'url': '', 'summary': ''})
#   ('world', {'url': '', 'summary': ''})
#   ('We spend more per student', {'url': '', 'summary': ''})
#   ('major country in the world', {'url': '', 'summary': ''})
#   ('Ronald Reagan', {'url': '', 'summary': ''})
#   ('re-election in 1984', {'url': '', 'summary': ''})
#   ('ran for re-election in 1984', {'url': '', 'summary': ''})
#   ('elementary schools', {'url': '', 'summary': ''})
#   ('art', {'url': '', 'summary': ''})
#   ('elementary school', {'url': '', 'summary': ''})
#   ('art instruction', {'url': '', 'summary': ''})
#   ('extreme poverty', {'url': '', 'summary': ''})
#   ('welfare reform', {'url': '', 'summary': ''})
#   ('poverty', {'url': '', 'summary': ''})
#   ('Bill Clinton', {'url': '', 'summary': ''})
#   ('state treasurer', {'url': '', 'summary': ''})
#   ('Illinois', {'url': '', 'summary': ''})
#   ('state government', {'url': '', 'summary': ''})
#   ('malaria', {'url': '', 'summary': ''})
#   ('Africa', {'url': '', 'summary': ''})
#   ('military expenditures', {'url': '', 'summary': ''})
#   ('military expenditures for the United States', {'url': '', 'summary': ''})
#   ('14 largest nations', {'url': '', 'summary': ''})
#   ('federal', {'url': '', 'summary': ''})
#   ('agencies', {'url': '', 'summary': ''})
#   ('federal job training programs', {'url': '', 'summary': ''})
#   ('eight agencies', {'url': '', 'summary': ''})
#   ('Dontre Hamilton', {'url': '', 'summary': ''})
#   ('Milwaukee', {'url': '', 'summary': ''})
#   ('Milwaukee police officer', {'url': '', 'summary': ''})
#   ('Keystone XL', {'url': '', 'summary': ''})
#   ('oil pipeline', {'url': '', 'summary': ''})
#   ('Keystone XL oil pipeline', {'url': '', 'summary': ''})
#   ('2001', {'url': '', 'summary': ''})
#   ('2007', {'url': '', 'summary': ''})
#   ('2001 to 2007', {'url': '', 'summary': ''})
#   ('Latino', {'url': '', 'summary': ''})
#   ('African-American', {'url': '', 'summary': ''})
#   ('1990s', {'url': '', 'summary': ''})
#   ('1990', {'url': '', 'summary': ''})
#   ('Bernie Sanders', {'url': '', 'summary': ''})
#   ('2016', {'url': '', 'summary': ''})
#   ('2008', {'url': '', 'summary': ''})
#   ('NJTV', {'url': '', 'summary': ''})
#   ('Paul Sarlo', {'url': '', 'summary': ''})
#   ('state Sen.', {'url': '', 'summary': ''})
#   ('Richard Nixon', {'url': '', 'summary': ''})
#   ('president', {'url': '', 'summary': ''})
#   ('Richard Nixon was president', {'url': '', 'summary': ''})
#   ('public office', {'url': '', 'summary': ''})
#   ('Sherrod Brown', {'url': '', 'summary': ''})
#   ('Share the Facts', {'url': '', 'summary': ''})
#   ('widget', {'url': '', 'summary': ''})
#   ('civil rights bill', {'url': '', 'summary': ''})
#   ('voting rights bill', {'url': '', 'summary': ''})
#   ('engineer', {'url': '', 'summary': ''})
#   ('scientist', {'url': '', 'summary': ''})
#   ('engineers', {'url': '', 'summary': ''})
#   ('scientists', {'url': '', 'summary': ''})
#   ('Democratic Party', {'url': '', 'summary': ''})
#   ('Republican counterparts', {'url': '', 'summary': ''})
#   ('2012 election', {'url': '', 'summary': ''})
#   ('2008 subprime crisis', {'url': '', 'summary': ''})
#   ('subprime market', {'url': '', 'summary': ''})
#   ('abuses', {'url': '', 'summary': ''})
#   ('primary care', {'url': '', 'summary': ''})
#   ('doctor', {'url': '', 'summary': ''})
#   ('doctors', {'url': '', 'summary': ''})
#   ('HIV', {'url': '', 'summary': ''})
#   ('AIDS', {'url': '', 'summary': ''})
#   ('sexually transmitted diseases', {'url': '', 'summary': ''})
#   ('prevention programs', {'url': '', 'summary': ''})
#   ('illegal immigrants', {'url': '', 'summary': ''})
#   ('retirement', {'url': '', 'summary': ''})
#   ('retiree', {'url': '', 'summary': ''})
#   ('paycheck', {'url': '', 'summary': ''})
#   ('constables', {'url': '', 'summary': ''})
#   ('Texas constables', {'url': '', 'summary': ''})
#   ('the line of duty', {'url': '', 'summary': ''})
#   ('Bush', {'url': '', 'summary': ''})
#   ("Children's Health Insurance Program", {'url': '', 'summary': ''})
#   ('President Bush', {'url': '', 'summary': ''})
#   ('repeal and replace', {'url': '', 'summary': ''})
#   ('PIP', {'url': '', 'summary': ''})
#   ('1,500', {'url': '', 'summary': ''})
#   ('highest corporate tax rate in the free world', {'url': '', 'summary': ''})
#   ('free world', {'url': '', 'summary': ''})
#   ('highest corporate tax rate', {'url': '', 'summary': ''})
#   ('Rick Perry', {'url': '', 'summary': ''})
#   ('in-state tuition... for illegal immigrants', {'url': '', 'summary': ''})
#   ('flawed strategy', {'url': '', 'summary': ''})
#   ('the country', {'url': '', 'summary': ''})
#   ('Chicago', {'url': '', 'summary': ''})
#   ('Los Angeles', {'url': '', 'summary': ''})
#   ('Houston', {'url': '', 'summary': ''})
#   ('Detroit', {'url': '', 'summary': ''})
#   ('Newark', {'url': '', 'summary': ''})
#   ('negative campaigning', {'url': '', 'summary': ''})
#   ('campaigns', {'url': '', 'summary': ''})
#   ('2008 Summer Olympics', {'url': '', 'summary': ''})
#   ('2004 Summer Olympics', {'url': '', 'summary': ''})
#   ('2004', {'url': '', 'summary': ''})
#   ('failed to pay his own taxes', {'url': '', 'summary': ''})
#   ('failed to pay his own taxes three separate times', {'url': '', 'summary': ''})
#   ('Atlanta metro area', {'url': '', 'summary': ''})
#   ('blacks', {'url': '', 'summary': ''})
#   ('metro area', {'url': '', 'summary': ''})
#   ('two-or four-year college', {'url': '', 'summary': ''})
#   ('high schools', {'url': '', 'summary': ''})
#   ('four-year college', {'url': '', 'summary': ''})
#   ('two-or four-year', {'url': '', 'summary': ''})
#   ('two-or four-year high schools', {'url': '', 'summary': ''})
#   ('49th', {'url': '', 'summary': ''})
#   ('businesses created', {'url': '', 'summary': ''})
#   ('49th in the United States', {'url': '', 'summary': ''})
#   ('2009', {'url': '', 'summary': ''})
#   ('nine years of declines', {'url': '', 'summary': ''})
#   ('Georgia', {'url': '', 'summary': ''})
#   ('Iowa', {'url': '', 'summary': ''})
#   ('Anglos', {'url': '', 'summary': ''})
#   ('Latinos', {'url': '', 'summary': ''})
#   ('oil reserves', {'url': '', 'summary': ''})
#   ("world's oil", {'url': '', 'summary': ''})
#   ('oil reserves in the world', {'url': '', 'summary': ''})
#   ('2', {'url': '', 'summary': ''})
#   ('drug laws', {'url': '', 'summary': ''})
#   ('drug use', {'url': '', 'summary': ''})
#   ('drug law', {'url': '', 'summary': ''})
#   ('2008 presidential election', {'url': '', 'summary': ''})
#   ('governor of California', {'url': '', 'summary': ''})
#   ('California', {'url': '', 'summary': ''})
#   ('Minnesota', {'url': '', 'summary': ''})
#   ('Oregon', {'url': '', 'summary': ''})
#   ('Treasury', {'url': '', 'summary': ''})
#   ('Crime Victim Compensation Program', {'url': '', 'summary': ''})
#   ('Kewpie', {'url': '', 'summary': ''})
#   ('Kewpie burger', {'url': '', 'summary': ''})
#   ('share of national population', {'url': '', 'summary': ''})
#   ('historical records', {'url': '', 'summary': ''})
#   ('immigration', {'url': '', 'summary': ''})
#   ('Tim Kaine', {'url': '', 'summary': ''})
#   ('tried to raise taxes by about 4 billion', {'url': '', 'summary': ''})
#   ('actually tried to raise taxes by about 4 billion', {'url': '', 'summary': ''})
#   ('small businesses', {'url': '', 'summary': ''})
#   ('middle-class families', {'url': '', 'summary': ''})
#   ('middle-class', {'url': '', 'summary': ''})
#   ('families', {'url': '', 'summary': ''})
#   ('flip-flopped', {'url': '', 'summary': ''})
#   ('tax returns', {'url': '', 'summary': ''})
#   ('David Perdue', {'url': '', 'summary': ''})
#   ('releasing his tax returns', {'url': '', 'summary': ''})
#   ('health care plan', {'url': '', 'summary': ''})
#   ('House Republican', {'url': '', 'summary': ''})
#   ('House Republican health care plan', {'url': '', 'summary': ''})
#   ('individual market', {'url': '', 'summary': ''})
#   ('president of Iran', {'url': '', 'summary': ''})
#   ('Supreme Court', {'url': '', 'summary': ''})
#   ('Saudi Arabia', {'url': '', 'summary': ''})
#   ('oil', {'url': '', 'summary': ''})
#   ('Saudis', {'url': '', 'summary': ''})
#   ('state funding', {'url': '', 'summary': ''})
#   ('education', {'url': '', 'summary': ''})
#   ('education today', {'url': '', 'summary': ''})
#   ('Reagans', {'url': '', 'summary': ''})
#   ('Reagans policies', {'url': '', 'summary': ''})
#   ('President Reagans', {'url': '', 'summary': ''})
#   ('hollow-point bullet', {'url': '', 'summary': ''})
#   ('bullet', {'url': '', 'summary': ''})
#   ('hollow-point bullets', {'url': '', 'summary': ''})
#   ('bullets', {'url': '', 'summary': ''})
#   ('Martini Bar', {'url': '', 'summary': ''})
#   ('Brazilian Steakhouse', {'url': '', 'summary': ''})
#   ('Steakhouse', {'url': '', 'summary': ''})
#   ('prior eight years', {'url': '', 'summary': ''})
#   ('increases in taxes and fees', {'url': '', 'summary': ''})
#   ('taxes and fees', {'url': '', 'summary': ''})
#   ('115 increases in taxes and fees', {'url': '', 'summary': ''})
#   ('budget bill', {'url': '', 'summary': ''})
#   ('House of Delegates', {'url': '', 'summary': ''})
#   ('House of Delegates budget bill', {'url': '', 'summary': ''})
#   ('Joni Ernst', {'url': '', 'summary': ''})
#   ('Iowa Senate', {'url': '', 'summary': ''})
#   ('VAWA', {'url': '', 'summary': ''})
#   ('1994', {'url': '', 'summary': ''})
#   ('Atlanta Mayor', {'url': '', 'summary': ''})
#   ('Kasim Reed', {'url': '', 'summary': ''})
#   ('end', {'url': '', 'summary': ''})
#   ('World War II', {'url': '', 'summary': ''})
#   ('the end', {'url': '', 'summary': ''})
#   ('drying up', {'url': '', 'summary': ''})
#   ('Venezuela', {'url': '', 'summary': ''})
#   ('oil money', {'url': '', 'summary': ''})
#   ('Venezuelan oil money', {'url': '', 'summary': ''})
#   ('President of the United States', {'url': '', 'summary': ''})
#   ('2000', {'url': '', 'summary': ''})
#   ('Rob Portman', {'url': '', 'summary': ''})
#   ('enslaved in 1850', {'url': '', 'summary': ''})
#   ('1850', {'url': '', 'summary': ''})
#   ('enslaved', {'url': '', 'summary': ''})
#   ('the campaign', {'url': '', 'summary': ''})
#   ('Fidel Castro', {'url': '', 'summary': ''})
#   ('Cuban Revolution', {'url': '', 'summary': ''})
#   ('Schedule I', {'url': '', 'summary': ''})
#   ('Controlled Substance Act', {'url': '', 'summary': ''})
#   ('heroin', {'url': '', 'summary': ''})
#   ('commutation', {'url': '', 'summary': ''})
#   ('pardon', {'url': '', 'summary': ''})
#   ('pardons', {'url': '', 'summary': ''})
#   ('clemencies', {'url': '', 'summary': ''})
#   ('prescription drug', {'url': '', 'summary': ''})
#   ('prices', {'url': '', 'summary': ''})
#   ('price', {'url': '', 'summary': ''})
#   ('athletic departments', {'url': '', 'summary': ''})
#   ('colleges and universities', {'url': '', 'summary': ''})
#   ('universities', {'url': '', 'summary': ''})
#   ('athletic department', {'url': '', 'summary': ''})
#   ('last budget', {'url': '', 'summary': ''})
#   ('state history', {'url': '', 'summary': ''})
#   ('unemployment law', {'url': '', 'summary': ''})
#   ('Louisiana', {'url': '', 'summary': ''})
#   ('Hillsborough County', {'url': '', 'summary': ''})
#   ('12', {'url': '', 'summary': ''})
#   ('1 percent sales tax', {'url': '', 'summary': ''})
#   ('humans are contributing to climate change', {'url': '', 'summary': ''})
#   ('scientific community', {'url': '', 'summary': ''})
#   ('scientific community believe that humans are contributing to climate change', {'url': '', 'summary': ''})
#   ('Gulf', {'url': '', 'summary': ''})
#   ('oil spill', {'url': '', 'summary': ''})
#   ('Wal-Mart', {'url': '', 'summary': ''})
#   ('Walton family', {'url': '', 'summary': ''})
#   ('2012 U.S. Senate campaign', {'url': '', 'summary': ''})
#   ('David Dewhurst', {'url': '', 'summary': ''})
#   ('pension reform', {'url': '', 'summary': ''})
#   ('17 years ago', {'url': '', 'summary': ''})
#   ('Pension reform', {'url': '', 'summary': ''})
#   ('Republican presidential candidate', {'url': '', 'summary': ''})
#   ('presidential candidate', {'url': '', 'summary': ''})
#   ('playoffs', {'url': '', 'summary': ''})
#   ('White Sox', {'url': '', 'summary': ''})
#   ('Health care premiums for consumers', {'url': '', 'summary': ''})
#   ('Health care premiums', {'url': '', 'summary': ''})
#   ('Crime is down in Arizona', {'url': '', 'summary': ''})
#   ('Arizona', {'url': '', 'summary': ''})
#   ('New Hampshire', {'url': '', 'summary': ''})
#   ('I cut the income tax', {'url': '', 'summary': ''})
#   ('tax cuts', {'url': '', 'summary': ''})
#   ('raised taxes in 2009', {'url': '', 'summary': ''})
#   ('Charlie Crist', {'url': '', 'summary': ''})
#   ('spankers', {'url': '', 'summary': ''})
#   ('parents', {'url': '', 'summary': ''})
#   ('spanking', {'url': '', 'summary': ''})
#   ('parent', {'url': '', 'summary': ''})
#   ('Asian-American', {'url': '', 'summary': ''})
#   ('Pacific Islander', {'url': '', 'summary': ''})
#   ('Walmart', {'url': '', 'summary': ''})
#   ('Romneycare', {'url': '', 'summary': ''})
#   ('pay and benefits', {'url': '', 'summary': ''})
#   ('federal employees', {'url': '', 'summary': ''})
#   ('Pay and benefits', {'url': '', 'summary': ''})
#   ('pay', {'url': '', 'summary': ''})
#   ('benefits', {'url': '', 'summary': ''})
#   ('1980', {'url': '', 'summary': ''})
#   ('suction entrapment', {'url': '', 'summary': ''})
#   ('swimming pool', {'url': '', 'summary': ''})
#   ('suction entrapment in swimming pools and spas', {'url': '', 'summary': ''})
#   ('insurance', {'url': '', 'summary': ''})
#   ('expense', {'url': '', 'summary': ''})
#   ('uninsured', {'url': '', 'summary': ''})
#   ('Americans', {'url': '', 'summary': ''})
#   ('Slavery', {'url': '', 'summary': ''})
#   ('punishment', {'url': '', 'summary': ''})
#   ('Wisconsin law', {'url': '', 'summary': ''})
#   ('called pregnant employees an inconvenience', {'url': '', 'summary': ''})
#   ('Donald Trump', {'url': '', 'summary': ''})
#   ('calls pregnant employees an inconvenience', {'url': '', 'summary': ''})
#   ('pregnant employees an inconvenience', {'url': '', 'summary': ''})
#   ('black name resume', {'url': '', 'summary': ''})
#   ('white name resume', {'url': '', 'summary': ''})
#   ('white nameresume', {'url': '', 'summary': ''})
#   ('November 2014 elections', {'url': '', 'summary': ''})
#   ('November 2014', {'url': '', 'summary': ''})
#   ('casino gambling', {'url': '', 'summary': ''})
#   ('Lyndon B. Johnson', {'url': '', 'summary': ''})
#   ('Lyndon B. Johnsons', {'url': '', 'summary': ''})
#   ('English', {'url': '', 'summary': ''})
#   ('states', {'url': '', 'summary': ''})
#   ('tests', {'url': '', 'summary': ''})
#   ('mandated tests', {'url': '', 'summary': ''})
#   ('Bob McDonnell', {'url': '', 'summary': ''})
#   ('Virginia', {'url': '', 'summary': ''})
#   ('Afghanistan', {'url': '', 'summary': ''})
#   ('negotiate down the national debt', {'url': '', 'summary': ''})
#   ('campuses', {'url': '', 'summary': ''})
#   ('Texas colleges and universities', {'url': '', 'summary': ''})
#   ('threat of shutdown', {'url': '', 'summary': ''})
#   ('shutdown', {'url': '', 'summary': ''})
#   ('double', {'url': '', 'summary': ''})
#   ('Obamas presidency', {'url': '', 'summary': ''})
#   ('double during Obamas presidency', {'url': '', 'summary': ''})
#   ('George Orwell', {'url': '', 'summary': ''})
#   ('Nineteen Eighty-Four', {'url': '', 'summary': ''})
#   ('Orwell', {'url': '', 'summary': ''})
#   ('Federal law', {'url': '', 'summary': ''})
#   ('Federal law prohibits the growing of industrial hemp in the United States', {'url': '', 'summary': ''})
#   ('15-an-hourproposal', {'url': '', 'summary': ''})
#   ('Cleveland', {'url': '', 'summary': ''})
#   ('15-an-hourproposal in Cleveland', {'url': '', 'summary': ''})
#   ('fought Obama', {'url': '', 'summary': ''})
#   ('won', {'url': '', 'summary': ''})
#   ('Abraham Lincoln', {'url': '', 'summary': ''})
#   ('slavery', {'url': '', 'summary': ''})
#   ('bought slavesfreedom in border states', {'url': '', 'summary': ''})
#   ('cut 40,000 spots', {'url': '', 'summary': ''})
#   ('Army', {'url': '', 'summary': ''})
#   ('40,000 spots', {'url': '', 'summary': ''})
#   ('Social Security', {'url': '', 'summary': ''})
#   ('16', {'url': '', 'summary': ''})
#   ('workers', {'url': '', 'summary': ''})
#   ('overdose deaths', {'url': '', 'summary': ''})
#   ('overdose', {'url': '', 'summary': ''})
#   ('opioid', {'url': '', 'summary': ''})
#   ('repeal', {'url': '', 'summary': ''})
#   ('repeal of Obamacare', {'url': '', 'summary': ''})
#   ('cap and trade', {'url': '', 'summary': ''})
#   ('58', {'url': '', 'summary': ''})
#   ('62', {'url': '', 'summary': ''})
#   ('new health care law', {'url': '', 'summary': ''})
#   ('health care law', {'url': '', 'summary': ''})
#   ('cures and treatments', {'url': '', 'summary': ''})
#   ('infomercials', {'url': '', 'summary': ''})
#   ('Cure', {'url': '', 'summary': ''})
#   ('treatments', {'url': '', 'summary': ''})
#   ('infomercial', {'url': '', 'summary': ''})
#   ('Glenn Grothman', {'url': '', 'summary': ''})
#   ('GOP', {'url': '', 'summary': ''})
#   ('Joe Leibham', {'url': '', 'summary': ''})
#   ('economy', {'url': '', 'summary': ''})
#   ('nations', {'url': '', 'summary': ''})
#   ('comprehensive reform', {'url': '', 'summary': ''})
#   ("his party's nomination", {'url': '', 'summary': ''})
#   ('McCain', {'url': '', 'summary': ''})
#   ('Seven Deadly Sins', {'url': '', 'summary': ''})
#   ('his book', {'url': '', 'summary': ''})
#   ('Social Security is unconstitutional', {'url': '', 'summary': ''})
#   ('unconstitutional', {'url': '', 'summary': ''})
#   ('health care reform negotiations', {'url': '', 'summary': ''})
#   ('health care reform', {'url': '', 'summary': ''})
#   ('national health insurance exchange', {'url': '', 'summary': ''})
#   ('25 million to 30 million', {'url': '', 'summary': ''})
#   ('health insurance exchange', {'url': '', 'summary': ''})
#   ('national', {'url': '', 'summary': ''})
#   ('25 million', {'url': '', 'summary': ''})
#   ('Coos County', {'url': '', 'summary': ''})
#   ('nationally', {'url': '', 'summary': ''})
#   ('gas pump', {'url': '', 'summary': ''})
#   ('grocery store', {'url': '', 'summary': ''})
#   ('more hours on the job', {'url': '', 'summary': ''})
#   ('bringing home smaller and smaller paychecks', {'url': '', 'summary': ''})
#   ('less time with their families', {'url': '', 'summary': ''})
#   ('unwanted sexual contact', {'url': '', 'summary': ''})
#   ('military', {'url': '', 'summary': ''})
#   ('women', {'url': '', 'summary': ''})
#   ('men', {'url': '', 'summary': ''})
#   ('sexual contact', {'url': '', 'summary': ''})
#   ('illegal', {'url': '', 'summary': ''})
#   ('12 states', {'url': '', 'summary': ''})
#   ('mixed marriage', {'url': '', 'summary': ''})
#   ('illegal in 12 states', {'url': '', 'summary': ''})
#   ('DREAM Act', {'url': '', 'summary': ''})
#   ('undocumented youth', {'url': '', 'summary': ''})
#   ('Marco Rubio', {'url': '', 'summary': ''})
#   ('Wisconsin school voucher program', {'url': '', 'summary': ''})
#   ('school voucher program', {'url': '', 'summary': ''})
#   ('school voucher', {'url': '', 'summary': ''})
#   ('never elected a Latina to Congress', {'url': '', 'summary': ''})
#   ('elected a Latina to Congress', {'url': '', 'summary': ''})
#   ('Koch brothers', {'url': '', 'summary': ''})
#   ('cheesemakers', {'url': '', 'summary': ''})
#   ('milk', {'url': '', 'summary': ''})
#   ('cheese', {'url': '', 'summary': ''})
#   ('Internet Protocol address', {'url': '', 'summary': ''})
#   ('unique', {'url': '', 'summary': ''})
#   ('supermax', {'url': '', 'summary': ''})
#   ('prison', {'url': '', 'summary': ''})
#   ('Department of Education', {'url': '', 'summary': ''})
#   ('teachers in Georgia', {'url': '', 'summary': ''})
#   ('mobile phone', {'url': '', 'summary': ''})
#   ('GPS', {'url': '', 'summary': ''})
#   ('American miracle', {'url': '', 'summary': ''})
#   ('United States government', {'url': '', 'summary': ''})
#   ('United States Senate', {'url': '', 'summary': ''})
#   ('1absentee record', {'url': '', 'summary': ''})
#   ('2018', {'url': '', 'summary': ''})
#   ('Zika', {'url': '', 'summary': ''})
#   ('its recess', {'url': '', 'summary': ''})
#   ('Medicare', {'url': '', 'summary': ''})
#   ('premiums', {'url': '', 'summary': ''})
#   ('premiums for Medicare', {'url': '', 'summary': ''})
#   ('65', {'url': '', 'summary': ''})
#   ('budget plan', {'url': '', 'summary': ''})
#   ('David Obey', {'url': '', 'summary': ''})
#   ('House Appropriations Chair', {'url': '', 'summary': ''})
#   ('39 years', {'url': '', 'summary': ''})
#   ('crime rate in 39 years', {'url': '', 'summary': ''})
#   ('binational health insurance program', {'url': '', 'summary': ''})
#   ('binational health insurance program with Mexico', {'url': '', 'summary': ''})
#   ('six months', {'url': '', 'summary': ''})
#   ('unemployed', {'url': '', 'summary': ''})
#   ('Illegal immigration', {'url': '', 'summary': ''})
#   ('crime', {'url': '', 'summary': ''})
#   ('crime rate', {'url': '', 'summary': ''})
#   ('third-lowest minimum wage', {'url': '', 'summary': ''})
#   ('developed countries', {'url': '', 'summary': ''})
#   ('third-lowest', {'url': '', 'summary': ''})
#   ('assault weapon', {'url': '', 'summary': ''})
#   ('gun', {'url': '', 'summary': ''})
#   ('assault weapons', {'url': '', 'summary': ''})
#   ('attack and kill Americans', {'url': '', 'summary': ''})
#   ('Al-Qaida', {'url': '', 'summary': ''})
#   ('attack and kill', {'url': '', 'summary': ''})
#   ('robust job growth', {'url': '', 'summary': ''})
#   ('rest of the nation', {'url': '', 'summary': ''})
#   ('corporations in this nation', {'url': '', 'summary': ''})
#   ('this nation', {'url': '', 'summary': ''})
#   ('middle class', {'url': '', 'summary': ''})
#   ('seniors', {'url': '', 'summary': ''})
#   ('senior', {'url': '', 'summary': ''})
#   ('capped', {'url': '', 'summary': ''})
#   ('tuition', {'url': '', 'summary': ''})
#   ('tuition was skyrocketing', {'url': '', 'summary': ''})
#   ('city', {'url': '', 'summary': ''})
#   ('2002 landslide', {'url': '', 'summary': ''})
#   ('Jeb Bush', {'url': '', 'summary': ''})
#   ('abortion rights', {'url': '', 'summary': ''})
#   ('background checks', {'url': '', 'summary': ''})
#   ('gun restrictions', {'url': '', 'summary': ''})
#   ('protests in Wisconsin', {'url': '', 'summary': ''})
#   ('protests', {'url': '', 'summary': ''})
#   ('economic plan', {'url': '', 'summary': ''})
#   ("Obama's", {'url': '', 'summary': ''})
#   ('paid family leave', {'url': '', 'summary': ''})
#   ('North Carolina', {'url': '', 'summary': ''})
#   ('college basketball', {'url': '', 'summary': ''})
#   ('economy the size of Italy', {'url': '', 'summary': ''})
#   ('Italy', {'url': '', 'summary': ''})
#   ('shes against banning assault weapons', {'url': '', 'summary': ''})
#   ('Carly Fiorina', {'url': '', 'summary': ''})
#   ('against banning assault weapons', {'url': '', 'summary': ''})
#   ('primary', {'url': '', 'summary': ''})
#   ('Democratic', {'url': '', 'summary': ''})
#   ('Democratic primary', {'url': '', 'summary': ''})
#   ('federal dollars', {'url': '', 'summary': ''})
#   ('federal school lunch assistance', {'url': '', 'summary': ''})
#   ('school lunch assistance', {'url': '', 'summary': ''})
#   ('82', {'url': '', 'summary': ''})
#   ('82 counties', {'url': '', 'summary': ''})
#   ('counties', {'url': '', 'summary': ''})
#   ('not done', {'url': '', 'summary': ''})
#   ('Brady bill', {'url': '', 'summary': ''})
#   ('Sen. Sanders', {'url': '', 'summary': ''})
#   ('bill', {'url': '', 'summary': ''})
#   ('income inequality', {'url': '', 'summary': ''})
#   ('In God We Trust', {'url': '', 'summary': ''})
#   ('Wayne Powell', {'url': '', 'summary': ''})
#   ('Legislature', {'url': '', 'summary': ''})
#   ('state Legislature', {'url': '', 'summary': ''})
#   ('2002 election', {'url': '', 'summary': ''})
#   ('deficits', {'url': '', 'summary': ''})
#   ('Weve seen our deficits cut by two-thirds', {'url': '', 'summary': ''})
#   ('bankruptcy', {'url': '', 'summary': ''})
#   ('technical college', {'url': '', 'summary': ''})
#   ('Occidental College', {'url': '', 'summary': ''})
#   ('1979', {'url': '', 'summary': ''})
#   ('shut the government down', {'url': '', 'summary': ''})
#   ('keep it open', {'url': '', 'summary': ''})
#   ('cost us more to shut the government down', {'url': '', 'summary': ''})
#   ('wind power', {'url': '', 'summary': ''})
#   ('all but four countries', {'url': '', 'summary': ''})
#   ('marriage licenses', {'url': '', 'summary': ''})
#   ('marriage license', {'url': '', 'summary': ''})
#   ('35 percent', {'url': '', 'summary': ''})
#   ('corporate tax rate', {'url': '', 'summary': ''})
#   ('corporate tax', {'url': '', 'summary': ''})
#   ('1', {'url': '', 'summary': ''})
#   ('unemployment rate', {'url': '', 'summary': ''})
#   ('7.8 percent', {'url': '', 'summary': ''})
#   ('five years', {'url': '', 'summary': ''})
#   ('maternal mortality rate', {'url': '', 'summary': ''})
#   ('Roe vs. Wade', {'url': '', 'summary': ''})
#   ('Americas maternal mortality rate', {'url': '', 'summary': ''})
#   ('Karen Handel', {'url': '', 'summary': ''})
#   ('Muslim armies', {'url': '', 'summary': ''})
#   ('armies', {'url': '', 'summary': ''})
#   ('Alex Jones', {'url': '', 'summary': ''})
#   ('Sandy Hook massacre', {'url': '', 'summary': ''})
#   ('child actor', {'url': '', 'summary': ''})
#   ('least intrusive count', {'url': '', 'summary': ''})
#   ('census', {'url': '', 'summary': ''})
#   ('intrusive count', {'url': '', 'summary': ''})
#   ('smallest and least intrusive count', {'url': '', 'summary': ''})
#   ('modern history', {'url': '', 'summary': ''})
#   ('graduation rate', {'url': '', 'summary': ''})
#   ('49th in the nation', {'url': '', 'summary': ''})
#   ('Newtown', {'url': '', 'summary': ''})
#   ('Ilana Shafran Mandels', {'url': '', 'summary': ''})
#   ('Forest City Enterprises', {'url': '', 'summary': ''})
#   ('Confederate battle flag in South Carolina', {'url': '', 'summary': ''})
#   ('South Carolina', {'url': '', 'summary': ''})
#   ('Confederate battle flag', {'url': '', 'summary': ''})
#   ('statehouse', {'url': '', 'summary': ''})
#   ('militarizing', {'url': '', 'summary': ''})
#   ('police', {'url': '', 'summary': ''})
#   ('militarizing the police', {'url': '', 'summary': ''})
#   ('defense industry', {'url': '', 'summary': ''})
#   ('Consumer Financial Protection Bureau', {'url': '', 'summary': ''})
#   ('Richard Cordray', {'url': '', 'summary': ''})
#   ('Richard Cordrays', {'url': '', 'summary': ''})
#   ('provide coverage for abortions', {'url': '', 'summary': ''})
#   ('coverage for abortions', {'url': '', 'summary': ''})
#   ('providing coverage for abortions', {'url': '', 'summary': ''})
#   ('votes with Obama 99 percent of the time', {'url': '', 'summary': ''})
#   ('votes with', {'url': '', 'summary': ''})
#   ('standing army', {'url': '', 'summary': ''})
#   ('substantial standing army', {'url': '', 'summary': ''})
#   ('a substantial standing army', {'url': '', 'summary': ''})
#   ('collective bargaining', {'url': '', 'summary': ''})
#   ('20 years ago', {'url': '', 'summary': ''})
#   ('same-sex marriage', {'url': '', 'summary': ''})
#   ('10 years ago', {'url': '', 'summary': ''})
#   ('Canada', {'url': '', 'summary': ''})
#   ('infrastructure needs in Atlanta', {'url': '', 'summary': ''})
#   ('minimum number of infrastructure needs in Atlanta', {'url': '', 'summary': ''})
#   ('cost-sharing requirement', {'url': '', 'summary': ''})
#   ('contraceptive coverage', {'url': '', 'summary': ''})
#   ('cancer', {'url': '', 'summary': ''})
#   ('affiliated issues', {'url': '', 'summary': ''})
#   ('costs of cancer', {'url': '', 'summary': ''})
#   ('Florida river systems', {'url': '', 'summary': ''})
#   ('drainage canal', {'url': '', 'summary': ''})
#   ('Florida river', {'url': '', 'summary': ''})
#   ('2005', {'url': '', 'summary': ''})
#   ('reduced its carbon emissions by 20 percent since 2005', {'url': '', 'summary': ''})
#   ('Bill Richardson', {'url': '', 'summary': ''})
#   ('National Guard', {'url': '', 'summary': ''})
#   ('Roadside bomb', {'url': '', 'summary': ''})
#   ('casualties in Iraq', {'url': '', 'summary': ''})
#   ('mine', {'url': '', 'summary': ''})
#   ('mine-resistant vehicle', {'url': '', 'summary': ''})
#   ('wages', {'url': '', 'summary': ''})
#   ('National Science Foundation', {'url': '', 'summary': ''})
#   ('climate change musical', {'url': '', 'summary': ''})
#   ('1992', {'url': '', 'summary': ''})
#   ('Google', {'url': '', 'summary': ''})
#   ('technology', {'url': '', 'summary': ''})
#   ('science and technology', {'url': '', 'summary': ''})
#   ('2011 election', {'url': '', 'summary': ''})
#   ('2011', {'url': '', 'summary': ''})
#   ('auto industry', {'url': '', 'summary': ''})
#   ('direct jobs', {'url': '', 'summary': ''})
#   ('money', {'url': '', 'summary': ''})
#   ('14', {'url': '', 'summary': ''})
#   ('14.1 trillion', {'url': '', 'summary': ''})
#   ('richest 80 people in the world', {'url': '', 'summary': ''})
#   ('bottom half of the global population', {'url': '', 'summary': ''})
#   ('global population', {'url': '', 'summary': ''})
#   ('Central America', {'url': '', 'summary': ''})
#   ('Mexican', {'url': '', 'summary': ''})
#   ('Floridas', {'url': '', 'summary': ''})
#   ('Kim Simac', {'url': '', 'summary': ''})
#   ('recall', {'url': '', 'summary': ''})
#   ('Ebola scare', {'url': '', 'summary': ''})
#   ('Dallas', {'url': '', 'summary': ''})
#   ('Ebola scare in Dallas', {'url': '', 'summary': ''})
#   ('inflation', {'url': '', 'summary': ''})
#   ('Daniel Webster', {'url': '', 'summary': ''})
#   ('speaker of the House', {'url': '', 'summary': ''})
#   ('Speaker of the House', {'url': '', 'summary': ''})
#   ('Dirty Dancing', {'url': '', 'summary': ''})
#   ('dance', {'url': '', 'summary': ''})
#   ('ban on "dirty dancing"', {'url': '', 'summary': ''})
#   ('food stamps', {'url': '', 'summary': ''})
#   ('family', {'url': '', 'summary': ''})
#   ('American', {'url': '', 'summary': ''})
#   ('most recent polls', {'url': '', 'summary': ''})
#   ('American people', {'url': '', 'summary': ''})
#   ('Atlanta Braves', {'url': '', 'summary': ''})
#   ('baseball', {'url': '', 'summary': ''})
#   ('professional sports franchise', {'url': '', 'summary': ''})
#   ('2017', {'url': '', 'summary': ''})
#   ('his plan', {'url': '', 'summary': ''})
#   ('medical marijuana', {'url': '', 'summary': ''})
#   ('prescribed', {'url': '', 'summary': ''})
#   ('the marketplace', {'url': '', 'summary': ''})
#   ('fossil fuel industry', {'url': '', 'summary': ''})
#   ('Richmond', {'url': '', 'summary': ''})
#   ('Va.', {'url': '', 'summary': ''})
#   ('Va', {'url': '', 'summary': ''})
#   ('Secretary Clinton', {'url': '', 'summary': ''})
#   ('Honduran', {'url': '', 'summary': ''})
#   ('Clinton', {'url': '', 'summary': ''})
#   ('Secretary', {'url': '', 'summary': ''})
#   ('Hillary Clinton', {'url': '', 'summary': ''})
#   ('embryonic stem cell research', {'url': '', 'summary': ''})
#   ('Bill McCollum', {'url': '', 'summary': ''})
#   ('stem cell research', {'url': '', 'summary': ''})
#   ('embryonic', {'url': '', 'summary': ''})
#   ('Europe', {'url': '', 'summary': ''})
#   ('top faculty pay and benefits', {'url': '', 'summary': ''})
#   ('faculty pay and benefits', {'url': '', 'summary': ''})
#   ('1920s', {'url': '', 'summary': ''})
#   ('1920', {'url': '', 'summary': ''})
#   ('the 1920s', {'url': '', 'summary': ''})
#   ('gap between the very rich and everyone else in America', {'url': '', 'summary': ''})
#   ('space station', {'url': '', 'summary': ''})
#   ('Russians', {'url': '', 'summary': ''})
#   ('federal level', {'url': '', 'summary': ''})
#   ('private sector', {'url': '', 'summary': ''})
#   ('Gross domestic product', {'url': '', 'summary': ''})
#   ('Senate immigration bill', {'url': '', 'summary': ''})
#   ('benefit', {'url': '', 'summary': ''})
#   ('newly legalized immigrants', {'url': '', 'summary': ''})
#   ('medication', {'url': '', 'summary': ''})
#   ('mental health treatment', {'url': '', 'summary': ''})
#   ('psychological distress', {'url': '', 'summary': ''})
#   ('Ive even cut my own salary', {'url': '', 'summary': ''})
#   ('twice', {'url': '', 'summary': ''})
#   ('Ive', {'url': '', 'summary': ''})
#   ('me', {'url': '', 'summary': ''})
#   ('two mansions', {'url': '', 'summary': ''})
#   ('Jeff Greene', {'url': '', 'summary': ''})
#   ('billionaire', {'url': '', 'summary': ''})
#   ('discriminated against women', {'url': '', 'summary': ''})
#   ('paid them less than men', {'url': '', 'summary': ''})
#   ('secretary of state', {'url': '', 'summary': ''})
#   ('Mental Illness', {'url': '', 'summary': ''})
#   ('death', {'url': '', 'summary': ''})
#   ('mental illness', {'url': '', 'summary': ''})
#   ('die an average of 25 years earlier', {'url': '', 'summary': ''})
#   ('die an average of 25 years earlier than those without a mental illness', {'url': '', 'summary': ''})
#   ('traditional marriage', {'url': '', 'summary': ''})
#   ('married couple', {'url': '', 'summary': ''})
#   ('wealthiest 25 percent', {'url': '', 'summary': ''})
#   ('Americas', {'url': '', 'summary': ''})
#   ('Wealthiest 5 percent', {'url': '', 'summary': ''})
#   ('pension', {'url': '', 'summary': ''})
#   ('pensioners', {'url': '', 'summary': ''})
#   ('pensions', {'url': '', 'summary': ''})
#   ('mentally', {'url': '', 'summary': ''})
#   ('physically fit', {'url': '', 'summary': ''})
#   ('physically fit to serve', {'url': '', 'summary': ''})
#   ('Chris Christie', {'url': '', 'summary': ''})
#   ('four years', {'url': '', 'summary': ''})
#   ('pro-life', {'url': '', 'summary': ''})
#   ('pro-gun', {'url': '', 'summary': ''})
#   ('New Jerseys', {'url': '', 'summary': ''})
#   ('Millennials', {'url': '', 'summary': ''})
#   ('age group', {'url': '', 'summary': ''})
#   ('millennials', {'url': '', 'summary': ''})
#   ('Millennial', {'url': '', 'summary': ''})
#   ('press conference', {'url': '', 'summary': ''})
#   ('seniors in America', {'url': '', 'summary': ''})
#   ('processed', {'url': '', 'summary': ''})
#   ('assassinated in 1963', {'url': '', 'summary': ''})
#   ('1963', {'url': '', 'summary': ''})
#   ('federal health care law', {'url': '', 'summary': ''})
#   ('8 months pregnant', {'url': '', 'summary': ''})
#   ('abortion', {'url': '', 'summary': ''})
#   ('pregnancy', {'url': '', 'summary': ''})
#   ('pregnant', {'url': '', 'summary': ''})
#   ('Bridge to Nowhere', {'url': '', 'summary': ''})
#   ('Patty Murray', {'url': '', 'summary': ''})
#   ('oil companies', {'url': '', 'summary': ''})
#   ('2012 elections', {'url': '', 'summary': ''})
#   ('national security', {'url': '', 'summary': ''})
#   ('national security satellite', {'url': '', 'summary': ''})
#   ('2016 Republican convention', {'url': '', 'summary': ''})
#   ('Republican convention', {'url': '', 'summary': ''})
#   ('Rhode Islands', {'url': '', 'summary': ''})
#   ('legislature', {'url': '', 'summary': ''})
#   ('Rhode Islands legislature', {'url': '', 'summary': ''})
#   ('infamous response', {'url': '', 'summary': ''})
#   ('opposed', {'url': '', 'summary': ''})
#   ('appointed', {'url': '', 'summary': ''})
#   ('elected', {'url': '', 'summary': ''})
#   ('government shutdown', {'url': '', 'summary': ''})
#   ('24 billion', {'url': '', 'summary': ''})
#   ('economy bled 24 billion', {'url': '', 'summary': ''})
#   ('Houston Rockets', {'url': '', 'summary': ''})
#   ('Dallas Cowboys', {'url': '', 'summary': ''})
#   ('trade agreement', {'url': '', 'summary': ''})
#   ('Kasichs budget', {'url': '', 'summary': ''})
#   ('state spending', {'url': '', 'summary': ''})
#   ('Alaska', {'url': '', 'summary': ''})
#   ('state tax on gasoline', {'url': '', 'summary': ''})
#   ('state tax', {'url': '', 'summary': ''})
#   ('gasoline', {'url': '', 'summary': ''})
#   ('immigration system', {'url': '', 'summary': ''})
#   ('an immigration system', {'url': '', 'summary': ''})
#   ('Healthcare Exchange', {'url': '', 'summary': ''})
#   ('healthcare plans', {'url': '', 'summary': ''})
#   ('private healthcare plans', {'url': '', 'summary': ''})
#   ('bankrupt four separate businesses', {'url': '', 'summary': ''})
#   ('bankrupt', {'url': '', 'summary': ''})
#   ('gun violence', {'url': '', 'summary': ''})
#   ('gun violence each year', {'url': '', 'summary': ''})
#   ('waterboarding', {'url': '', 'summary': ''})
#   ('terrorists', {'url': '', 'summary': ''})
#   ('Ron Paul', {'url': '', 'summary': ''})
#   ('foreign policy', {'url': '', 'summary': ''})
#   ('voting record', {'url': '', 'summary': ''})
#   ('mammogram', {'url': '', 'summary': ''})
#   ('mammography providers', {'url': '', 'summary': ''})
#   ('mammography provider', {'url': '', 'summary': ''})
#   ('prescription drug program', {'url': '', 'summary': ''})
#   ('health care', {'url': '', 'summary': ''})
#   ('expanded government health care', {'url': '', 'summary': ''})
#   ('government health care', {'url': '', 'summary': ''})
#   ('reproductive health care', {'url': '', 'summary': ''})
#   ('womans right to make her own decisions', {'url': '', 'summary': ''})
#   ('right to make her own decisions', {'url': '', 'summary': ''})
#   ('Harry Truman', {'url': '', 'summary': ''})
#   ('White House', {'url': '', 'summary': ''})
#   ('the White House', {'url': '', 'summary': ''})
#   ('30s', {'url': '', 'summary': ''})
#   ('30', {'url': '', 'summary': ''})
#   ('Turkeys today', {'url': '', 'summary': ''})
#   ('29.8 pounds', {'url': '', 'summary': ''})
#   ('hospital', {'url': '', 'summary': ''})
#   ('care', {'url': '', 'summary': ''})
#   ('care they receive', {'url': '', 'summary': ''})
#   ('hospitalized', {'url': '', 'summary': ''})
#   ('Jeff Vanderbeek', {'url': '', 'summary': ''})
#   ('New Jersey Devils', {'url': '', 'summary': ''})
#   ('08-09', {'url': '', 'summary': ''})
#   ('raised the national debt 18 times', {'url': '', 'summary': ''})
#   ('raised the national debt', {'url': '', 'summary': ''})
#   ('sanctuary cities', {'url': '', 'summary': ''})
#   ('Massachusetts', {'url': '', 'summary': ''})
#   ('Sanctuary cities', {'url': '', 'summary': ''})
#   ('equal pay', {'url': '', 'summary': ''})
#   ('equal work', {'url': '', 'summary': ''})
#   ('Equal Pay Act', {'url': '', 'summary': ''})
#   ('women earn equal pay', {'url': '', 'summary': ''})
#   ('equal pay for equal work', {'url': '', 'summary': ''})
#   ('earn equal pay', {'url': '', 'summary': ''})
#   ('bankrupted his companies', {'url': '', 'summary': ''})
#   ('bankrupted his companies not once, not twice but four times', {'url': '', 'summary': ''})
#   ('Rick Santorum', {'url': '', 'summary': ''})
#   ('conservative', {'url': '', 'summary': ''})
#   ('illegal aliens', {'url': '', 'summary': ''})
#   ('invested', {'url': '', 'summary': ''})
#   ('invested in a company', {'url': '', 'summary': ''})
#   ('administration', {'url': '', 'summary': ''})
#   ('under the Obama administration', {'url': '', 'summary': ''})
#   ('nearly doubled', {'url': '', 'summary': ''})
#   ('Obama administration', {'url': '', 'summary': ''})
#   ('Floridians', {'url': '', 'summary': ''})
#   ('Middle East', {'url': '', 'summary': ''})
#   ('migrants', {'url': '', 'summary': ''})
# ...
#   {'head': 'semi-automatic firearm', 'type': 'use', 'tail': 'hunting', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'semi-automatic firearms', 'type': 'use', 'tail': 'hunting', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'never once had a majority of Americans favor it', 'type': 'instance of', 'tail': 'bill', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'never once had a majority of Americans favor it', 'type': 'is a list of', 'tail': 'bill', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'never once had a majority of Americans favor it', 'type': 'subclass of', 'tail': 'bill', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Medicaid', 'type': 'part of', 'tail': 'Obamacare', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'partition', 'type': 'country', 'tail': 'Iraq', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'partition of Iraq', 'type': 'country', 'tail': 'Iraq', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Iraq', 'type': 'instance of', 'tail': 'partition', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Dick Lugar', 'type': 'member of political party', 'tail': 'Republican', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Sen. Dick Lugar', 'type': 'member of political party', 'tail': 'Republican', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'economy', 'type': 'location', 'tail': 'Texas', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'economy', 'type': 'located in the administrative territorial entity', 'tail': 'Texas', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Texas', 'type': 'instance of', 'tail': 'country', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'opponents of the health care law', 'type': 'court', 'tail': 'U.S. Supreme Court', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'health care law', 'type': 'main subject', 'tail': 'opponents of the health care law', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'two main arguments', 'type': 'main subject', 'tail': 'health care law', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': '1948', 'type': 'successful candidate', 'tail': 'Dwight Eisenhower', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'insurance commissioners', 'type': 'applies to jurisdiction', 'tail': 'North Carolina', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'insurance commissioner', 'type': 'applies to jurisdiction', 'tail': 'states', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Number of Americans killed by terrorism in the last decade', 'type': 'number of participants', 'tail': '24', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Number of Americans killed by guns in the last decade', 'type': 'number of participants', 'tail': '280,024', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Americans killed by terrorism in the last decade', 'type': 'number of participants', 'tail': '24', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'state treasurer', 'type': 'applies to jurisdiction', 'tail': 'Rhode Island', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'state treasurer', 'type': 'located in the administrative territorial entity', 'tail': 'Rhode Island', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Rhode Island', 'type': 'office held by head of government', 'tail': 'state treasurer', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'exception for rape', 'type': 'facet of', 'tail': 'abortion', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'exception for rape', 'type': 'subclass of', 'tail': 'abortion', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'rape', 'type': 'facet of', 'tail': 'abortion', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Border Patrol', 'type': 'instance of', 'tail': 'agents', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Mitt Romney', 'type': 'residence', 'tail': 'Bermuda', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'corporation', 'type': 'owned by', 'tail': 'Mitt Romney', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'a corporation', 'type': 'owned by', 'tail': 'Mitt Romney', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'military', 'type': 'opposite of', 'tail': 'civilian counterparts', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'civilian counterparts', 'type': 'opposite of', 'tail': 'military', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'military', 'type': 'opposite of', 'tail': 'civilian', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'anti-abortion', 'type': 'facet of', 'tail': 'womens health', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'anti-abortion', 'type': 'located in the administrative territorial entity', 'tail': 'Texas', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'anti-abortion', 'type': 'facet of', 'tail': 'womens health services', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'CEO pay', 'type': 'facet of', 'tail': 'Corporate profits', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'CEO pay', 'type': 'has effect', 'tail': 'Corporate profits', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'CEO pay is up', 'type': 'facet of', 'tail': 'Corporate profits are up', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Williamson County Attorney', 'type': 'officeholder', 'tail': 'Jana Duty', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Jana Duty', 'type': 'position held', 'tail': 'Williamson County Attorney', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Williamson County', 'type': 'head of government', 'tail': 'Jana Duty', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Hewlett-Packard', 'type': 'instance of', 'tail': 'company', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Hewlett-Packard', 'type': 'instance of', 'tail': 'the company', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Hewlett-Packard', 'type': 'follows', 'tail': 'Packard', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Packard', 'type': 'followed by', 'tail': 'Hewlett-Packard', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Mitt Romney', 'type': 'work location', 'tail': 'Ohio', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Mitt Romney', 'type': 'residence', 'tail': 'Ohio', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Ohio', 'type': 'head of state', 'tail': 'Mitt Romney', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'his own budget', 'type': 'named after', 'tail': 'Paul Ryan', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'his own budget', 'type': 'author', 'tail': 'Paul Ryan', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'own budget', 'type': 'named after', 'tail': 'Paul Ryan', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'highest corporate tax rates in the world', 'type': 'point in time', 'tail': 'right now', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'highest corporate tax rates', 'type': 'country', 'tail': 'the world', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'highest corporate tax rates in the world right now', 'type': 'point in time', 'tail': 'right now', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'motorcycle', 'type': 'country of origin', 'tail': 'American', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'borrowed', 'type': 'country', 'tail': 'U.S.', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'China', 'type': 'instance of', 'tail': 'borrowed', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'borrowed', 'type': 'subclass of', 'tail': 'dollar', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'New Jersey', 'type': 'instance of', 'tail': 'states', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'New Jersey', 'type': 'country', 'tail': 'this country', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'this country', 'type': 'contains administrative territorial entity', 'tail': 'New Jersey', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'New Jersey', 'type': 'instance of', 'tail': 'states in this country', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'uses of deadly force by police', 'type': 'country', 'tail': 'United States', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'uses of deadly force by police in the United States', 'type': 'country', 'tail': 'United States', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'uses of deadly force', 'type': 'used by', 'tail': 'police', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'state history', 'type': 'facet of', 'tail': 'Georgia', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'state history under GOP watch', 'type': 'facet of', 'tail': 'Georgia', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'National Guard', 'type': 'country', 'tail': 'United States', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'chambers of commerce', 'type': 'applies to jurisdiction', 'tail': 'Texas', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'chambers of commerce', 'type': 'located in the administrative territorial entity', 'tail': 'Texas', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'welfare', 'type': 'applies to jurisdiction', 'tail': 'Wisconsin', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Wisconsin governor', 'type': 'applies to jurisdiction', 'tail': 'Wisconsin', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Ronald Reagans', 'type': 'position held', 'tail': 'presidency', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'presidency', 'type': 'officeholder', 'tail': 'Ronald Reagans', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'presidency', 'type': 'facet of', 'tail': 'Ronald Reagans', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Amtrak', 'type': 'number of trips', 'tail': '40', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Amtrak', 'type': 'number of episodes', 'tail': '40', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Amtrak', 'type': 'owner of', 'tail': 'its entire 40-year history', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'its entire 40-year history', 'type': 'owned by', 'tail': 'Amtrak', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'animal cruelty laws', 'type': 'applies to jurisdiction', 'tail': 'state', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'animal cruelty laws', 'type': 'subclass of', 'tail': 'law', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'state animal cruelty laws', 'type': 'part of', 'tail': 'state budget', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Paul Ryan budget proposal', 'type': 'main subject', 'tail': 'Medicare', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Paul Ryan budget proposal', 'type': 'facet of', 'tail': 'Medicare', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Paul Ryan budget proposal', 'type': 'instance of', 'tail': 'privatize Medicare', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Bush', 'type': 'significant event', 'tail': 'Reconciliation', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Bush', 'type': 'participant in', 'tail': 'Reconciliation', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'tax cuts for the rich', 'type': 'instance of', 'tail': 'Reconciliation', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'condoms', 'type': 'subclass of', 'tail': 'origami', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'condom', 'type': 'subclass of', 'tail': 'origami', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'condom', 'type': 'uses', 'tail': 'origami', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Lieutenant Governor', 'type': 'subclass of', 'tail': 'governor', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Lieutenant Governor', 'type': 'subclass of', 'tail': 'lieutenant governors', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'South Florida', 'type': 'country', 'tail': 'the country', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'South Florida', 'type': 'country', 'tail': 'country', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'shootings of Dallas policemen', 'type': 'location', 'tail': 'Dallas', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'shootings of Dallas policemen', 'type': 'located in the administrative territorial entity', 'tail': 'Dallas', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'shootings', 'type': 'location', 'tail': 'Dallas', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Sarah Palin', 'type': 'spouse', 'tail': 'Barack Obama', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Joe Biden', 'type': 'influenced by', 'tail': 'Barack Obama', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Barack Obama', 'type': 'spouse', 'tail': 'Sarah Palin', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Texas', 'type': 'ranking', 'tail': 'dead last', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Texas', 'type': 'ranking', 'tail': 'last in support for mental health', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Texas', 'type': 'instance of', 'tail': 'last in support for mental health', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Georgia Lottery', 'type': 'instance of', 'tail': 'prizes', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'last fiscal year', 'type': 'part of', 'tail': 'Georgia Lottery', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'last fiscal year', 'type': 'instance of', 'tail': 'Georgia Lottery', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Time magazine', 'type': 'country of origin', 'tail': 'America', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Time magazine', 'type': 'has part', 'tail': "America's best governors", 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Time magazine', 'type': 'country of origin', 'tail': "America's", 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'home sales', 'type': 'part of', 'tail': 'crisis', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'housing crisis of 2008', 'type': 'point in time', 'tail': '2008', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'home sales are up nearly 50 percent from where they were in the worst of the crisis', 'type': 'is a list of', 'tail': 'home sales', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'large game hunting', 'type': 'subclass of', 'tail': 'hunters', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'magazine', 'type': 'connects with', 'tail': 'cartridge', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'cartridge', 'type': 'connects with', 'tail': 'magazine', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'magazine', 'type': 'different from', 'tail': 'cartridge', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'cartridge', 'type': 'different from', 'tail': 'magazine', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': '2008 London Olympics', 'type': 'point in time', 'tail': '2008', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Bernie Sanders', 'type': 'country of citizenship', 'tail': 'Soviet Union', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Bernie Sanders', 'type': 'residence', 'tail': 'Soviet Union', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Bernie Sanders', 'type': 'work location', 'tail': 'Soviet Union', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Hewlett-Packard', 'type': 'owner of', 'tail': 'Compaq', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Compaq', 'type': 'owned by', 'tail': 'Hewlett-Packard', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Hewlett-Packard', 'type': 'subsidiary', 'tail': 'Compaq', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Compaq', 'type': 'parent organization', 'tail': 'Hewlett-Packard', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Hewlett-Packard', 'type': 'follows', 'tail': 'Compaq', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Compaq', 'type': 'followed by', 'tail': 'Hewlett-Packard', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': '2000 Florida election', 'type': 'point in time', 'tail': '2000', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': '2000 Florida election', 'type': 'applies to jurisdiction', 'tail': 'Florida', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'purge a list of felons', 'type': 'point in time', 'tail': '2000', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Penny Plan', 'type': 'named after', 'tail': 'Connie Macks', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Penny Plan', 'type': 'author', 'tail': 'Connie Macks', 'meta': {'': {'spans': [[0, 64]]}}}
#   {'head': 'Penny Plan', 'type': 'creator', 'tail': 'Connie Macks', 'meta': {'': {'spans': [[0, 64]]}}}
# Sources:
#   ('', {'article_title': None, 'article_publish_date': None})
# (7946, None)

# %%
filename = f"LIAR_real_entites_intermediate_RAW_{articles_limit}.html"
save_kb(kb, os.path.basename(filename)[:-5]  + ".p")
